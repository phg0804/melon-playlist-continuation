# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Load Data

# %% [markdown]
# ### Load genre_gn_all.json

# %%
genre_gn_all = pd.read_json('./data/genre_gn_all.json', typ = 'series', encoding = 'UTF-8')
genre_gn_all = pd.DataFrame(genre_gn_all, columns = ['gnr_name']).reset_index().rename(columns = {'index' : 'gnr_code'})
genre_gn_all.head()
# Out:
#   gnr_code gnr_name
# 0   GN0100      발라드
# 1   GN0101   세부장르전체
# 2   GN0102      '80
# 3   GN0103      '90
# 4   GN0104      '00

# %% [markdown]
# ### Load song_meta.json

# %%
song_meta = pd.read_json('./data/song_meta.json', orient='values', encoding = 'UTF-8')

# %%
song_meta = song_meta.set_index('id')
song_meta.head()
# Out:
#     album_id                                         album_name  \
# id
# 0    2255639                       불후의 명곡 - 7080 추억의 얄개시대 팝송베스트
# 1     376431                      Bach : Partitas Nos. 2, 3 & 4
# 2    4698747                                                Hit
# 3    2644882  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4    2008470                                            그남자 그여자
#
#    artist_id_basket artist_name_basket  issue_date song_gn_dtl_gnr_basket  \
# id
# 0            [2727]  [Various Artists]    20140512               [GN0901]
# 1           [29966]   [Murray Perahia]    20080421       [GN1601, GN1606]
# 2            [3361]    [Peter Gabriel]    20180518               [GN0901]
# 3          [838543]           [Matoma]    20151016       [GN1102, GN1101]
# 4          [560160]         [Jude Law]    20110824       [GN1802, GN1801]
#
#    song_gn_gnr_basket                                          song_name
# id
# 0            [GN0900]                                           Feelings
# 1            [GN1600]  Bach : Partita No. 4 In D Major, BWV 828 - II....
# 2            [GN0900]                    Solsbury Hill (Remastered 2002)
# 3            [GN1100]  Feeling Right (Everything Is Nice) (Feat. Popc...
# 4            [GN1800]                                            그남자 그여자

# %% [markdown]
# ### Load train.json

# %%
train_data = pd.read_json('./data/train.json', encoding = 'UTF-8')
train_data.head()
# Out:
#        id  like_cnt           plylst_title  \
# 0   61281        71                여행같은 음악
# 1   10532         1                요즘 너 말야
# 2   76951        17  편하게, 잔잔하게 들을 수 있는 곡.-
# 3  147456        33  크리스마스 분위기에 흠뻑 취하고 싶을때
# 4   27616         9               추억의 노래 ㅋ
#
#                                                songs  \
# 0  [525514, 129701, 383374, 562083, 297861, 13954...
# 1  [432406, 675945, 497066, 120377, 389529, 24427...
# 2  [83116, 276692, 166267, 186301, 354465, 256598...
# 3  [394031, 195524, 540149, 287984, 440773, 10033...
# 4  [159327, 553610, 5130, 645103, 294435, 100657,...
#
#                                                 tags                updt_date
# 0                                                [락]  2013-12-19 18:36:19.000
# 1                                           [추억, 회상]  2014-12-02 16:19:42.000
# 2                                          [까페, 잔잔한]  2017-08-28 07:09:34.000
# 3  [연말, 눈오는날, 캐럴, 분위기, 따듯한, 크리스마스캐럴, 겨울노래, 크리스마스,...  2019-12-05 15:15:18.000
# 4                                               [댄스]  2011-10-25 13:54:56.000

# %% [markdown]
# - playlist id - songs 맵핑

# %%
# 플레이리스트 아이디(id)와 수록곡(songs) 추출
plylst_song_map = train_data[['id', 'songs']]

# unnest songs
plylst_song_map_unnest = np.dstack(
    (
        np.repeat(plylst_song_map.id.values, list(map(len, plylst_song_map.songs))), 
        np.concatenate(plylst_song_map.songs.values)
    )
)

# unnested 데이터프레임 생성 : plylst_song_map
plylst_song_map = pd.DataFrame(data = plylst_song_map_unnest[0], columns = plylst_song_map.columns)
plylst_song_map['id'] = plylst_song_map['id'].astype(str)
plylst_song_map['songs'] = plylst_song_map['songs'].astype(str)

# unnest 객체 제거
del plylst_song_map_unnest

# %%
plylst_song_map.head()
# Out:
#       id   songs
# 0  61281  525514
# 1  61281  129701
# 2  61281  383374
# 3  61281  562083
# 4  61281  297861

# %%
# 1. 곡 별 수록된 플레이리스트 개수 count 테이블 생성 : song_plylst_cnt
song_plylst_cnt = plylst_song_map.groupby('songs').id.nunique().reset_index(name = 'mapping_plylst_cnt')

# 2. 단일/중복 수록 구분 : 곡 별 수록된 플레이리스트가 한 개면 '단일 수록', 두 개 이상이면 '중복 수록'
song_plylst_cnt = song_plylst_cnt.assign(
    mapping_plylst_cnt_category = pd.cut(song_plylst_cnt['mapping_plylst_cnt'], [0, 9, np.inf], labels = ['10회 미만', '10회 이상'])
)

# %%
# 10회 이상 나오는 곡의 수
len(song_plylst_cnt[song_plylst_cnt.mapping_plylst_cnt_category == '10회 이상'].songs)
# Out:
# 81221

# %%
plylst_song_map_filter = plylst_song_map[plylst_song_map.songs.isin(song_plylst_cnt[song_plylst_cnt.mapping_plylst_cnt_category == '10회 이상'].songs)]

# %%
print(plylst_song_map.shape)
print(plylst_song_map_filter.shape)
# Out:
# (5285871, 2)
# (4123576, 2)

# %%
train_data = train_data.set_index('id')

# tag list를 하나의 리스트로 합쳐주는 함수
def merge_list(lst):
    out = set()
    for sublst in lst:
        out = out.union(set(sublst))
    return list(out)

merge_list(train_data.loc[[61281, 10532, 147456], :].loc[:, 'tags'].values)
# Out:
# ['회상',
#  '따듯한',
#  '캐럴',
#  '크리스마스송',
#  '크리스마스캐럴',
#  '연말',
#  '겨울노래',
#  '락',
#  '눈오는날',
#  '추억',
#  '겨울왕국',
#  '크리스마스',
#  '분위기']

# %% [markdown]
# **아래 코드 8분 정도 소요됨**

# %%
song_tag_map = plylst_song_map_filter.groupby('songs').apply(lambda x : merge_list(train_data.loc[x['id'].values.astype(np.int32), :].tags))
song_tag_map.head()
# Out:
# songs
# 10        [회상, 겨울, 카페, 연주곡, 로파이힙합, Chill, 감성, Lofihiphop...
# 1000      [로멘틱, 겨울, 뉴에이지, 팝, 카페, 연주곡, 배경음악, 연말, Chill, 월...
# 100011    [겨울, 회상, 팝, 카페, 일요일, 위로, 연말, 산책, 신나는, 휴식, 기분전환...
# 100014    [뉴에이지, 몽환, 연주곡, 힐링, 산책, 휴식, 기분전환, 매장음악, 새벽, 까페...
# 100020    [요가음악, 요가, 뉴에이지, 카페, 공부, 연주곡, 위로, 휴식, 북카페, 편안한...
# dtype: object

# %%
song_tag_map_frame = pd.DataFrame(song_tag_map)
song_tag_map_frame = song_tag_map_frame.rename(columns = {0 : 'tags'})
song_tag_map_frame = song_tag_map_frame.reset_index()
song_tag_map_frame.head()
# Out:
#     songs                                               tags
# 0      10  [회상, 겨울, 카페, 연주곡, 로파이힙합, Chill, 감성, Lofihiphop...
# 1    1000  [로멘틱, 겨울, 뉴에이지, 팝, 카페, 연주곡, 배경음악, 연말, Chill, 월...
# 2  100011  [겨울, 회상, 팝, 카페, 일요일, 위로, 연말, 산책, 신나는, 휴식, 기분전환...
# 3  100014  [뉴에이지, 몽환, 연주곡, 힐링, 산책, 휴식, 기분전환, 매장음악, 새벽, 까페...
# 4  100020  [요가음악, 요가, 뉴에이지, 카페, 공부, 연주곡, 위로, 휴식, 북카페, 편안한...

# %%
# 전체 태그 set 만들기
tags = set({})
for subtags in song_tag_map_frame.tags.values:
    tags = tags.union(set(subtags))
len(tags) # 전체 태그 수
# Out:
# 27619

# %%
# 태그 set -> dictionary
tags_dict = {list(tags)[i]: i for i in range(len(tags))}

# %%
tags_dict['휴식']
# Out:
# 19827

# %%
# 태그 -> id
song_tag_map_frame.tags = song_tag_map_frame.tags.apply(lambda x : [tags_dict[t] for t in x])

# %%
song_tag_map_frame.head()
# Out:
#     songs                                               tags
# 0      10  [19881, 22680, 13581, 7424, 9570, 19666, 16886...
# 1    1000  [18650, 22680, 16764, 12907, 13581, 7424, 1142...
# 2  100011  [22680, 19881, 12907, 13581, 26209, 20145, 319...
# 3  100014  [16764, 10989, 7424, 17586, 1344, 19827, 21640...
# 4  100020  [2114, 14320, 16764, 13581, 6123, 7424, 20145,...

# %% [markdown]
# Save song_tag_map_frame to csv file

# %%
song_tag_map_frame.to_csv(path_or_buf='song_tag_id_map.csv', encoding='UTF-8')

# %%
song_tag_map_frame.to_pickle(path = '../song_tag_id_map.pkl')

# %% [markdown]
# ### Load val.json

# %%
val_data = pd.read_json('./data/val.json', encoding = 'UTF-8')
val_data.head()
# Out:
#        id  like_cnt plylst_title  \
# 0  118598      1675
# 1  131447         1       앨리스테이블
# 2   51464        62
# 3   45144        20
# 4   79929        20
#
#                                                songs tags  \
# 0  [373313, 151080, 275346, 696876, 165237, 52593...   []
# 1                                                 []   []
# 2  [529437, 516103, 360067, 705713, 226062, 37089...   []
# 3  [589668, 21711, 570151, 320043, 13930, 599327,...   []
# 4  [672718, 121924, 102694, 683657, 201558, 38511...   []
#
#                  updt_date
# 0  2019-05-27 14:14:33.000
# 1  2014-07-16 15:24:24.000
# 2  2008-06-21 23:26:22.000
# 3  2017-10-30 18:15:43.000
# 4  2017-02-07 11:40:42.000

# %%
val_data.shape
# Out:
# (23015, 6)

# %%
val_data[(val_data.songs.apply(len) == 0) & (val_data.tags.apply(len) == 0)]
# Out:
#            id  like_cnt                              plylst_title songs tags  \
# 1      131447         1                                    앨리스테이블    []   []
# 9      142007         0                   기분 좋은 재즈와 함께 만드는 달달한 하루    []   []
# 35      65114         6                        ■■■■ 사랑,그리고이별 ■■■■    []   []
# 57      87700         6                           마쉬멜로우같은 멜로우한 음악    []   []
# 71      35271        10                        공부와 독서를 위한 #Newage    []   []
# 101     85920         0                              새벽에 감성 돋는 노래    []   []
# 115    122041         0                        인디, OST 음악을 만나다 50    []   []
# 135     62695        20                          너 없이 살수가 없어(그리움)    []   []
# 167    116425      2548                      귀를 달달하게 만들어주는 남녀 듀엣곡    []   []
# 199     67281        18                           ★기분전환 K-POP 뮤직★    []   []
# 218    108550       415                              냉정과 열정사이, 가을    []   []
# 220    120921         5              나른한 오후 카페에 앉아 커피를 마시며 듣는 연주곡    []   []
# 221    148561         2                                      발라드드    []   []
# 240     24084        12                후기 바로크 11(17세기후~18세기중)-바흐4    []   []
# 253     61075         0                              신나는 곡/좋아하는 곡    []   []
# 254    106113        19                  흔하지 않아서 더 특별한 여성 보컬 모음곡.    []   []
# 257     52235         0                             클래식과 함께하는 퇴근길    []   []
# 279      6997         1                                 봄봄봄봄봄이왔어요    []   []
# 300     37367         5                                   취향저격 팝송    []   []
# 304    136311        13                     구름을 걷는 듯한 <솜사탕같은 제이팝>    []   []
# 307     59819       169                ♥뜨거운 햇살 아래 시원한 그늘 같은 여성 보컬    []   []
# 308    152162         0                            주말을 마무리하며 듣는음악    []   []
# 317     55481         6                           신해경이라는 장르로 힐링하기    []   []
# 333     11708        27                           5회 아시아송페스티벌...★    []   []
# 334     25040         3                               위로가 되어주는 인디    []   []
# 352     66718         1                                   좋아하는 노래    []   []
# 379    146969       697                              매혹적인 아카펠라 재즈    []   []
# 384     99780         9                                      달달보스    []   []
# 391     17587         2                       락페스티벌이 생각나는 국내 밴드음악    []   []
# 400    140065        11                        밤에 찾게 되는 알앤비 소울 :)    []   []
# ...       ...       ...                                       ...   ...  ...
# 22700  128448       791                             힐링,위로,태교 뉴에이지    []   []
# 22705  128008        11                            달콤한 훈남들의 노래열전!    []   []
# 22707    7615         8                                   라디오 396    []   []
# 22730  143159        19                               보들보들 힐링찬양!!    []   []
# 22731  140201         5                                 그사람이 그리울때    []   []
# 22741   84241         2                          서정적인 노래 모음（≧∇≦）!    []   []
# 22743   69111         0                     맘이 편해지려면...그와함꼐있어야합니다    []   []
# 22744   55599         2                            2008 인천 펜타포트 락    []   []
# 22748   44238         1                                   힘이되는 노래    []   []
# 22762   29123         3                            가을비와 함께 듣는 발라드    []   []
# 22765   16106        68                    동부 힙합 오리지널 붐뱁으로만 엄선했다!    []   []
# 22769  116719         2                                 보고싶다는 말조차    []   []
# 22785   12666         2                         비오는 날엔, 스타일리쉬한 재즈    []   []
# 22795   74539         1                           언제나 들어도 좋은노래(1)    []   []
# 22800   76037         9                     새해에는 꼭 운동을! 운동을 위한 음악    []   []
# 22810  114056      1491                           스피닝 탈 때 자주듣는 노래    []   []
# 22812  142251         0                     파란 하늘처럼 눈부시게 다가오는 음악들    []   []
# 22816   13755        12                           상큼하고 특색있는 보컬 모음    []   []
# 22830   22014         3                                              []   []
# 22831   96049        25                  힐링여행 (마음을 다스리는 34색 명상음악)    []   []
# 22845   57033         1          2000년대초 인디음악을 대중음악으로 성공 시킨 명곡 모음    []   []
# 22849   94638         5                          위클리 초이스 - 7월 5째주    []   []
