# %%
from datetime import timedelta, datetime
import glob
from itertools import chain
import json
import os
import re

import numpy as np
import pandas as pd

from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from konlpy.tag import Twitter
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

from pandas.plotting import register_matplotlib_converters
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# %%
# Numpy Matrix
# Column : Each song
# Row : Shingles



# Instance variables :
# n : the number of total songs
# s : the number of signatures
# r : the number of signatures in a single band
# b : the number of bands (s // r)
# perm : permutated np array
# mhdata : minhashed (signature array) 
#          row : signatures / columns : songs
# ---------------------------------------------------------------
import numpy as np 
import pandas as pd
import time

class LSH() :
    # Initializer
    # Input
    # data : pandas dataframe for song - shingles
    #        row : songs / column : array of tags for each song
    # tag_dic : dictionary with key : tag / value : integer
    # sig_n : the number of signatures
    # band_r : the number of signatures in a single band
    # bucket_sz : bucket size for LSH
    # -----------------------------------------------------------
    def __init__(self, data, tag_dic, sig_n, band_r) :
        self.data = data
        self.tag_dic = tag_dic
        self.n = data.shape[0]
        self.s = sig_n
        self.r = band_r
        self.bucket_sz = 20000
        if self.s%self.r != 0 :
            print("The number of signatures is not divided by the number of band_r.")
            print("Warning : Remainder signatures will be ignored")
            self.s = self.s - self.s%self.r
        self.b  = self.s // self.r
        self.song_dic = dict(zip(self.data.iloc[:,0],range(len(self.data.iloc[:,0]))))   #index 0 might change
        # converts array of tag to array of integers
        self.data['tags'] = [[tag_dic.get(key) for key in i] for i in data.iloc[:,1]]   #index 1 might change
            
    # permutation
    # save random shuffle of 1:n 
    def permute(self, tag_n) :
        self.perm = np.random.permutation(tag_n)
        
    # This function uses permutation to hash, outputs the minimum value
    # tag_n : Total number of tags (required for permutation)
    # This algorithm could be improved using
    # https://datalab.snu.ac.kr/~ukang/courses/19S-DM/L5-lsh.pdf page 42 later
    def minhash(self, tag_n = None) :   
        # result matrix
        # row : signatures / columns : songs
        s_t = time.time()
        sig_mat = np.zeros((self.s, self.n))
        for sig_num in range(self.s) :
            self.permute(tag_n)
            new_sig = [min(np.take(self.perm, i)) for i in self.data.iloc[:,1]]  # index 1 could be changed later
            sig_mat[sig_num, :] = new_sig
            print("Minhash {0} : {1}".format(sig_num, time.time()-s_t))
        self.mhdata = sig_mat
        
    
    # This function locally hashes the signature vector (of size self.r)
    def local_hash(self, sig_vec) :
        return hash(str(sig_vec)) % self.bucket_sz
    
    # Computes locally sensitive hashing algorithm (put into buckets)
    # Bucket_mtx : row - bands, column - bucket for each band 
    def lsh(self) :
        mh_t = np.transpose(self.mhdata)
        bucket_mtx = np.empty((self.b, self.bucket_sz), object)
        for band_i in range(self.b) :
            s_t = time.time()
            curr = band_i * self.r 
            hashed = [self.local_hash(col[curr:curr+self.r]) for col in mh_t]
            for ind, item in enumerate(hashed, start=0): 
                bucket_mtx[band_i][item] = np.append(bucket_mtx[band_i][item], ind)
            print("Band {0} : {1}".format(band_i, time.time()-s_t))        
        self.bucket_mtx = bucket_mtx
        
    def lsh_dic(self) :
        mh_t = np.transpose(self.mhdata)
        bucket_dic = {}
        for band_i in range(self.b) :
            s_t = time.time()
            curr = band_i * self.r 
            hashed = [self.local_hash(col[curr:curr+self.r]) for col in mh_t]
            for ind, item in enumerate(hashed, start=0): 
                try : 
                    bucket_dic[(band_i,item)] = np.append(bucket_dic[(band_i,item)], ind)
                except KeyError :
                    bucket_dic[(band_i,item)] = [ind]               
            print("Band {0} : {1}".format(band_i, time.time()-s_t))        
        self.bucket_dic = bucket_dic
    
    def mid_level(self, tag_n = None) :
        self.minhash(tag_n)
        self.lsh()
    
    # Outputs the array of similar songs w.r.t given song
    def sim_items(self, song) :
        sim_item = np.array([])
        song_sig = self.mhdata[:,self.song_dic[song]]
        for band_i in range(self.b) :
            s_t = time.time()
            curr = band_i * self.r
            curr_hash_val = self.local_hash(song_sig[curr:curr+self.r])
            bucket_for_this = self.bucket_mtx[band_i][curr_hash_val]
            sim_item = np.union1d(sim_item, list(filter(None, bucket_for_this)))
            print("Find Similar Items / Band {0} : {1}".format(band_i, time.time()-s_t))
        return list(np.take(self.data.iloc[:, 0], sim_item, axis = 0)) # index 0 might change
    
    
        # Outputs the array of similar songs w.r.t given song
    def sim_items_dic(self, song) :
        sim_item = np.array([])
        song_sig = self.mhdata[:,self.song_dic[song]]
        for band_i in range(self.b) :
            s_t = time.time()
            curr = band_i * self.r
            curr_hash_val = self.local_hash(song_sig[curr:curr+self.r])
            bucket_for_this = self.bucket_dic[(band_i, curr_hash_val)]
            sim_item = np.union1d(sim_item, bucket_for_this)
            #print("Find Similar Items / Band {0} : {1}".format(band_i, time.time()-s_t))
        return np.array(np.take(self.data.iloc[:, 0], sim_item, axis = 0)) # index 0 might change

# %%
import pandas as pd
data = pd.read_pickle("song_tag_map.pkl")
tag_dict = pd.read_csv("tag_id_dict.csv")
tag_dict.to_dict
tag_dic = tag_dict.set_index('Unnamed: 0')['0'].to_dict()
tag_dic[''] = 28742

# %%
#data
# sig_n : the number of signature 
# band_r : the number of bands (for lsh)
# higher band_r requires longer time for each band calculation, but shorter overall running time
# higher band_r will output smaller number of similar items
# band_r should divide sig_n (if possible)
lsh = LSH(data, tag_dic, sig_n = 20, band_r = 5)
lsh.mid_level(28743)
lsh.lsh_dic()
# Should input song number as following form ('10') not 10
# Out:
# Minhash 0 : 2.190100908279419
# Minhash 1 : 4.366220951080322
# Minhash 2 : 6.59139609336853
# Minhash 3 : 8.807657957077026
# Minhash 4 : 10.941670894622803
# Minhash 5 : 13.088166952133179
# Minhash 6 : 15.297792911529541
# Minhash 7 : 17.420285940170288
# Minhash 8 : 19.79772686958313
# Minhash 9 : 22.320438861846924
# Minhash 10 : 24.90955901145935
# Minhash 11 : 27.099628925323486
# Minhash 12 : 29.24092698097229
# Minhash 13 : 31.385441064834595
# Minhash 14 : 33.468711853027344
# Minhash 15 : 35.520264863967896
# Minhash 16 : 37.64385199546814
# Minhash 17 : 39.73874878883362
# Minhash 18 : 41.86536502838135
# Minhash 19 : 44.039198875427246
# Band 0 : 20.332006692886353
# Band 1 : 20.95531702041626
# Band 2 : 21.09306287765503
# Band 3 : 20.43804907798767
# Band 0 : 20.274312019348145
# Band 1 : 21.062299966812134
# Band 2 : 21.546303272247314
# Band 3 : 21.492562770843506

# %%
#후보가 되는 곡들의 dictionary를 출력
def answer(songs_know, lsh):
    # ------------ input -------------
    # songs_know : playlist에 있는 songs들을 담은 list
    
    
    candidate_songs = dict()
    
    for song in songs_know:
        
        #함수 이름 앵버가 짜면 바꿔야 함
        if not(str(song) in list(lsh.data['songs'])):
            continue
        toadd = lsh.sim_items_dic(str(song))
        
        # candidate_songs에서 얼만큼 언급되었는지 세어준다
        for it in toadd:
            if(it in candidate_songs):
                candidate_songs[it] += 1
            else: #처음 등장한 녀석
                candidate_songs[it] = 1
    
    candidate_songs = dict(sorted(candidate_songs.items(), reverse=True, key=lambda item: item[1]))
    
    return candidate_songs


#answer2가 진짜 답을 추출함
def answer2(candidate_songs_dict, songs_know):
    real_candidate = list(candidate_songs_dict.keys())
    for song in songs_know:
        if(str(song) in real_candidate):
            real_candidate.remove(str(song))
    if(len(real_candidate) < 100):
        #add_baseline(real_candidate)
        pass
    else:
        real_candidate = real_candidate[0:100]
    
    rc2 = []
    for song in real_candidate:
        rc2.append(int(song))
    
    return rc2


def trythisone(songs_know, lsh):
    answer = []
    
    for song in songs_know:
        if not(str(song) in list(lsh.data['songs'])):
            continue
        toadd = list(lsh.sim_items_dic(str(song)))
        
        answer = list(set(answer + toadd))
        
        if(len(answer) >= 100):
            break
            
    if(len(answer) >= 100):
        return [int(i) for i in answer[0:100]]
    else:
        return list(range(1,101))

# %%
valid = pd.read_json('val.json', typ = 'frame')

# %%
import json

file_path = "./results2.json"

datum = []

for index, row in valid.iterrows():
    res = trythisone(row['songs'], lsh)
    datum.append({'id' : row['id'] , 'songs' : res, 'tags' : ['타린','간지러워','점수','에드시런셋리스트','첩보영화','우아한','화사한','피아노','힙합스타일','싱숭생숭']})
    if(index % 500 == 0):
        print(index)

with open(file_path, 'w') as outfile:
    json.dump(datum, outfile)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000

# %%
results = pd.read_json('results2.json', typ = 'frame')

# %%
#results만 제출하려서 빈 곳들(곡이 없는 경우)에 뭐라도 채워 넣어야 해서 채워넣음

file_path = "./secondresults.json"

datum = []

for index, row in results.iterrows():
    if(len(row['songs']) != 100):
        datum.append({'id' : row['id'] , 'songs' : res2, 'tags' : ['타린','간지러워','점수','에드시런셋리스트','첩보영화','우아한','화사한','피아노','힙합스타일','싱숭생숭']})
    else:    
        datum.append({'id' : row['id'] , 'songs' : row['songs'], 'tags' : ['타린','간지러워','점수','에드시런셋리스트','첩보영화','우아한','화사한','피아노','힙합스타일','싱숭생숭']})
    if(index % 500 == 0):
        print(index)

with open(file_path, 'w') as outfile:
    json.dump(datum, outfile)
# Out:
#            id                                              songs  \
# 0      118598  [642087, 680584, 54195, 375411, 381087, 472456...
# 1      131447                                                 []
# 2       51464  [110911, 134401, 224670, 264288, 284009, 34673...
# 3       45144  [160925, 230582, 286975, 367905, 375907, 41986...
# 4       79929  [290421, 464118, 106208, 107570, 14343, 149375...
# 5      138538  [100105, 100127, 100453, 100820, 101283, 10143...
# 6      127575  [14069, 142686, 148498, 174250, 219583, 223363...
# 7      115317  [360566, 156818, 268976, 271064, 282469, 29723...
# 8       80810                                                 []
# 9      142007                                                 []
# 10     126307  [427723, 427835, 101404, 10834, 113331, 118897...
# 11     136650  [100145, 100346, 100492, 100720, 100737, 10083...
# 12      53131  [25875, 229404, 142404, 144454, 175164, 215219...
# 13      44037  [58857, 612017, 61482, 70168, 117193, 138049, ...
# 14      64105  [28750, 268942, 297953, 378736, 413197, 48276,...
# 15      40637  [254008, 102694, 277334, 137782, 147046, 16909...
# 16      41828  [10016, 102544, 107841, 109679, 110504, 111744...
# 17       2380                                                 []
# 18      87846  [573518, 131351, 302160, 361084, 36374, 391166...
# 19      94446  [633029, 199665, 136079, 195215, 102436, 15195...
# 20     149069                                                 []
# 21       7373  [17482, 114795, 145705, 311349, 342361, 37451,...
# 22      74934  [208535, 688159, 59650, 171939, 174501, 181992...
# 23      29647  [130882, 151100, 186481, 227328, 252183, 30885...
# 24     105642  [699999, 270312, 124410, 146765, 154562, 15587...
# 25      41619                                                 []
# 26     150267  [105198, 225674, 261014, 473768, 640017, 12045...
# 27      65872  [177931, 25422, 290940, 427752, 580349, 111239...
# 28      93962  [500760, 223246, 39317, 42345, 445855, 535398,...
# 29     100937  [481241, 164090, 239766, 542344, 57189, 353304...
# ...       ...                                                ...
# 22985  107874  [172013, 189981, 63470, 72281, 136799, 104433,...
# 22986   57486  [159859, 186412, 203812, 218729, 260036, 29696...
# 22987  150610  [557931, 66347, 696300, 526517, 550026, 102318...
# 22988    5678  [440024, 130774, 184277, 287569, 38603, 392600...
# 22989   90166  [321630, 186219, 461952, 597038, 148651, 45087...
# 22990    8848  [40905, 494006, 34024, 555481, 61521, 510337, ...
# 22991   32537                                                 []
# 22992   32812                                                 []
# 22993   12782  [252090, 462815, 153597, 100935, 120902, 13203...
# 22994  131409  [319054, 57968, 103028, 12116, 130140, 130943,...
# 22995   72661  [1023, 102533, 111552, 114586, 114697, 117025,...
# 22996   86721                                                 []
# 22997   75905  [412968, 345537, 108035, 116065, 136722, 13742...
# 22998  144021  [13772, 296364, 571162, 426800, 688738, 670667...
# 22999  104033  [150814, 285833, 320537, 384714, 497248, 50519...
# 23000    6951  [186638, 2463, 14566, 15719, 186336, 210273, 2...
# 23001   11721  [122947, 134215, 135210, 145346, 148403, 15700...
# 23002   56570                                                 []
# 23003  127349  [221720, 245352, 25615, 409249, 478289, 53627,...
# 23004  127228  [132370, 236655, 342576, 355644, 369828, 41212...
# 23005  136258                                                 []
# 23006   92067  [35448, 691632, 624815, 172095, 284885, 481925...
# 23007   44013  [166439, 297685, 598223, 599412, 77074, 81969,...
# 23008  100684                                                 []
# 23009   17766  [600313, 144578, 337272, 378218, 257056, 28359...
# 23010  101722  [691916, 264053, 361744, 241885, 320633, 53459...
# 23011  122127  [542557, 70097, 58982, 116567, 100912, 296571,...
# 23012   77438  [253671, 45493, 57957, 438229, 507191, 531268,...
# 23013   36231  [232890, 101531, 117712, 197406, 207760, 26525...
# 23014   65189  [335659, 11204, 134855, 17707, 197617, 202496,...
#
#                                                     tags
# 0      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 1      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 2      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 3      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 4      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 5      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 6      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 7      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 8      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 9      [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 10     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 11     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 12     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 13     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 14     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 15     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 16     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 17     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 18     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 19     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 20     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 21     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 24     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 25     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 26     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 27     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 28     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 29     [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# ...                                                  ...
# 22985  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22986  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22987  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22988  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22989  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22990  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22991  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22992  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22993  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22994  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22995  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22996  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22997  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22998  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 22999  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23000  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23001  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23002  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23003  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23004  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23005  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23006  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23007  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23008  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23009  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23010  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23011  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23012  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23013  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
# 23014  [타린, 간지러워, 점수, 에드시런셋리스트, 첩보영화, 우아한, 화사한, 피아노, ...
#
# [23015 rows x 3 columns]

# %%
datum
# Out:
# [{'id': 118598,
#   'songs': [644079,
#    640905,
#    590806,
#    275346,
#    373313,
#    563557,
#    659521,
#    160041,
#    127445,
#    242159,
#    430919,
#    251889,
#    642713,
#    126796,
#    127481,
#    210628,
#    151189,
#    24016,
#    502007,
#    648503,
#    680113,
#    304527,
#    470379,
#    228552,
#    450241,
#    642138,
#    438507,
#    426967,
#    278204,
#    665448,
#    122193,
#    54090,
#    532982,
#    151080,
#    560854,
#    676778,
#    189617,
#    318946,
#    523299,
#    397882,
#    506623,
#    191409,
#    697770,
#    169956,
#    629896,
#    403593,
#    97178,
#    421952,
#    178058,
#    1628,
#    165343,
#    20271,
#    466188,
#    323327,
#    623454,
#    600856,
#    540535,
#    566506,
#    152578,
#    554044,
#    140718,
#    52029,
#    131897,
#    155328,
#    266903,
#    129112,
#    231994,
#    695353,
#    372245,
#    175171,
#    36745,
#    310883,
#    73007,
#    31842,
#    12972,
#    252915,
#    269952,
#    356674,
#    102749,
#    662616,
#    272085,
#    41163,
#    611581,
#    108763,
#    220665,
#    686904,
#    528059,
#    80571,
#    499918,
#    131407,
#    707167,
#    321381,
#    353263,
#    323369,
#    228855,
#    378627,
#    420604,
#    489677,
#    143583,
#    467180],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 131447,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 51464,
#   'songs': [545303,
#    621119,
#    528422,
#    594146,
#    449401,
#    628996,
#    160563,
#    231434,
#    595150,
#    463509,
#    120885,
#    365176,
#    304756,
#    561832,
#    671447,
#    634375,
#    423392,
#    248407,
#    511248,
#    344269,
#    9631,
#    262343,
#    629251,
#    614439,
#    582560,
#    149601,
#    704199,
#    139310,
#    414877,
#    15258,
#    650010,
#    210255,
#    359355,
#    149882,
#    359980,
#    441237,
#    498133,
#    52429,
#    197665,
#    680122,
#    423399,
#    151302,
#    464702,
#    73283,
#    362296,
#    175282,
#    637727,
#    221070,
#    157752,
#    705422,
#    242643,
#    707252,
#    189031,
#    554033,
#    112915,
#    79349,
#    671409,
#    187709,
#    43435,
#    334735,
#    550732,
#    392525,
#    267903,
#    386160,
#    462141,
#    529437,
#    592376,
#    144783,
#    442855,
#    621956,
#    209531,
#    404629,
#    526084,
#    547462,
#    670336,
#    466443,
#    543242,
#    620367,
#    138515,
#    124401,
#    677302,
#    404561,
#    88730,
#    374765,
#    390178,
#    181982,
#    209882,
#    383955,
#    663046,
#    401276,
#    669040,
#    608497,
#    592047,
#    232576,
#    686739,
#    374326,
#    556869,
#    83364,
#    549716,
#    197803],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 45144,
#   'songs': [242111,
#    438618,
#    362516,
#    308649,
#    675296,
#    109845,
#    342130,
#    125602,
#    620231,
#    103683,
#    105932,
#    109977,
#    432968,
#    349075,
#    18286,
#    124290,
#    148152,
#    13113,
#    484998,
#    377425,
#    339319,
#    312099,
#    264505,
#    516297,
#    78807,
#    504806,
#    294046,
#    430479,
#    611215,
#    362489,
#    681732,
#    589668,
#    159721,
#    449138,
#    308867,
#    616602,
#    6980,
#    424243,
#    346307,
#    277441,
#    604353,
#    14905,
#    136212,
#    233880,
#    149276,
#    596645,
#    537779,
#    638255,
#    9764,
#    610891,
#    79061,
#    519587,
#    600574,
#    604601,
#    683833,
#    205930,
#    461763,
#    181589,
#    73109,
#    695527,
#    275332,
#    89562,
#    393037,
#    453172,
#    100290,
#    275135,
#    21711,
#    306448,
#    144128,
#    697979,
#    481283,
#    44922,
#    85855,
#    536518,
#    302189,
#    1839,
#    601836,
#    247408,
#    108610,
#    298597,
#    54211,
#    178130,
#    641227,
#    605654,
#    16874,
#    373336,
#    87482,
#    329777,
#    183701,
#    653460,
#    587188,
#    500085,
#    35084,
#    54837,
#    653661,
#    525516,
#    555282,
#    101562,
#    506694,
#    570489],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 79929,
#   'songs': [240608,
#    508967,
#    121924,
#    293986,
#    624478,
#    348743,
#    260425,
#    51590,
#    309825,
#    483425,
#    83320,
#    334276,
#    296704,
#    652299,
#    309805,
#    416394,
#    673353,
#    695525,
#    672718,
#    566756,
#    269905,
#    523152,
#    308345,
#    529074,
#    496638,
#    212751,
#    355706,
#    306666,
#    248466,
#    64808,
#    671672,
#    154349,
#    55864,
#    506065,
#    374517,
#    649443,
#    300387,
#    71451,
#    328670,
#    498635,
#    613246,
#    519338,
#    559180,
#    163074,
#    102694,
#    397160,
#    202450,
#    608669,
#    42811,
#    671559,
#    685561,
#    262942,
#    618982,
#    406965,
#    239999,
#    685339,
#    613740,
#    432315,
#    8315,
#    204627,
#    50947,
#    338036,
#    385536,
#    176560,
#    516039,
#    329913,
#    542071,
#    176684,
#    678825,
#    650747,
#    49468,
#    213640,
#    676018,
#    17236,
#    273352,
#    70868,
#    489396,
#    471577,
#    542663,
#    671112,
#    328765,
#    533891,
#    512148,
#    560111,
#    493642,
#    6558,
#    311871,
#    679536,
#    5120,
#    704547,
#    514576,
#    642796,
#    540344,
#    390727,
#    264965,
#    541399,
#    200366,
#    668076,
#    340593,
#    157886],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 138538,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 127575,
#   'songs': [227044,
#    225332,
#    273008,
#    256839,
#    555736,
#    491860,
#    548457,
#    561378,
#    203617,
#    528759,
#    141532,
#    424672,
#    138417,
#    437996,
#    536389,
#    343974,
#    124802,
#    469415,
#    44060,
#    581309,
#    141089,
#    189800,
#    651975,
#    561434,
#    592992,
#    24512,
#    311215,
#    34620,
#    446141,
#    67091,
#    462800,
#    537339,
#    236627,
#    647419,
#    166705,
#    232713,
#    614889,
#    357064,
#    218911,
#    680360,
#    193450,
#    664451,
#    280119,
#    291327,
#    696911,
#    376414,
#    671600,
#    110019,
#    626524,
#    473400,
#    439805,
#    560726,
#    564545,
#    23397,
#    41864,
#    189733,
#    587895,
#    638181,
#    661537,
#    85700,
#    257116,
#    168695,
#    338632,
#    660398,
#    647877,
#    112078,
#    259588,
#    50756,
#    424390,
#    378721,
#    157129,
#    635625,
#    359981,
#    35077,
#    379821,
#    575423,
#    248083,
#    159069,
#    131121,
#    317107,
#    395002,
#    515592,
#    601187,
#    472381,
#    258984,
#    139751,
#    548192,
#    618958,
#    102361,
#    370838,
#    567541,
#    440568,
#    59381,
#    176018,
#    321067,
#    90911,
#    255404,
#    46273,
#    697871,
#    236382],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 115317,
#   'songs': [313834,
#    203101,
#    93551,
#    59727,
#    449091,
#    106773,
#    25930,
#    70639,
#    241125,
#    58424,
#    245648,
#    196199,
#    317127,
#    119140,
#    226552,
#    516634,
#    41713,
#    594436,
#    694902,
#    128526,
#    520275,
#    121331,
#    666649,
#    128703,
#    653539,
#    64438,
#    262521,
#    701731,
#    667742,
#    84140,
#    632923,
#    217735,
#    292473,
#    427952,
#    541404,
#    309641,
#    376162,
#    395512,
#    54457,
#    57110,
#    571171,
#    310612,
#    122523,
#    621503,
#    130212,
#    150756,
#    543992,
#    89795,
#    614780,
#    585448,
#    279049,
#    256946,
#    218713,
#    355339,
#    269097,
#    430311,
#    468813,
#    652921,
#    461345,
#    440678,
#    105716,
#    669042,
#    218022,
#    649697,
#    525704,
#    672201,
#    498904,
#    654513,
#    413491,
#    107583,
#    678950,
#    228217,
#    546407,
#    318042,
#    258004,
#    357454,
#    310586,
#    654062,
#    684881,
#    589691,
#    314809,
#    72141,
#    52861,
#    653999,
#    250233,
#    676948,
#    63039,
#    668270,
#    496043,
#    239758,
#    95508,
#    102361,
#    525727,
#    240814,
#    297395,
#    88552,
#    216298,
#    176018,
#    625860,
#    631852],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 80810,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 142007,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 126307,
#   'songs': [352884,
#    464131,
#    319046,
#    632089,
#    369419,
#    691545,
#    624939,
#    213042,
#    436345,
#    554986,
#    275593,
#    652689,
#    542673,
#    493150,
#    535158,
#    265149,
#    439924,
#    329864,
#    428384,
#    567265,
#    640558,
#    220579,
#    580750,
#    707264,
#    552922,
#    484442,
#    552223,
#    396400,
#    396304,
#    397644,
#    520983,
#    279323,
#    680625,
#    463018,
#    332676,
#    21725,
#    390958,
#    342027,
#    72127,
#    22913,
#    338290,
#    585859,
#    233634,
#    585030,
#    366786,
#    70314,
#    141555,
#    605355,
#    677672,
#    48934,
#    53883,
#    703619,
#    287846,
#    332144,
#    130187,
#    424430,
#    315883,
#    556666,
#    187924,
#    224503,
#    572332,
#    529937,
#    17765,
#    348789,
#    14985,
#    365800,
#    263525,
#    659565,
#    336269,
#    454082,
#    545195,
#    38935,
#    87693,
#    672267,
#    472516,
#    66709,
#    233146,
#    485514,
#    112246,
#    35857,
#    261442,
#    85130,
#    71307,
#    183008,
#    456829,
#    565720,
#    187798,
#    673008,
#    439411,
#    168190,
#    142372,
#    43580,
#    351561,
#    432300,
#    116853,
#    362319,
#    587195,
#    74942,
#    548427,
#    219304],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 136650,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 53131,
#   'songs': [597166,
#    565753,
#    549413,
#    212268,
#    533227,
#    615026,
#    624949,
#    531422,
#    534107,
#    204290,
#    217710,
#    277567,
#    642441,
#    129018,
#    47040,
#    624325,
#    680435,
#    612286,
#    191153,
#    260085,
#    117337,
#    392257,
#    272092,
#    32766,
#    24540,
#    613023,
#    532824,
#    654991,
#    535018,
#    164056,
#    500053,
#    580222,
#    608415,
#    596917,
#    67003,
#    368860,
#    583188,
#    640787,
#    651579,
#    97536,
#    138677,
#    58513,
#    562390,
#    475913,
#    354156,
#    8507,
#    276347,
#    422646,
#    668879,
#    250577,
#    305286,
#    406471,
#    303619,
#    77619,
#    288795,
#    302038,
#    31451,
#    624138,
#    5084,
#    255827,
#    100473,
#    365915,
#    496999,
#    65304,
#    170073,
#    531624,
#    507924,
#    614923,
#    484240,
#    441477,
#    267336,
#    454273,
#    652932,
#    34612,
#    537830,
#    377742,
#    572362,
#    123717,
#    552650,
#    670862,
#    379341,
#    308106,
#    184782,
#    319703,
#    686926,
#    657097,
#    473726,
#    247839,
#    423749,
#    37581,
#    10380,
#    15764,
#    21985,
#    244065,
#    649134,
#    2946,
#    98273,
#    120485,
#    657683,
#    368955],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 44037,
#   'songs': [357783,
#    563099,
#    44321,
#    10805,
#    441208,
#    405033,
#    429294,
#    502078,
#    507118,
#    331119,
#    534672,
#    298833,
#    659952,
#    670029,
#    687670,
#    81616,
#    161138,
#    32494,
#    164890,
#    154662,
#    378556,
#    502065,
#    337329,
#    540460,
#    355315,
#    220088,
#    418950,
#    55764,
#    687598,
#    338050,
#    432216,
#    609905,
#    543913,
#    400370,
#    589389,
#    26804,
#    644040,
#    518153,
#    208682,
#    261662,
#    599856,
#    411984,
#    86396,
#    705518,
#    254823,
#    574064,
#    496911,
#    348369,
#    99895,
#    162808,
#    657833,
#    56699,
#    434196,
#    3040,
#    246402,
#    644431,
#    176863,
#    697446,
#    523418,
#    675869,
#    465523,
#    288393,
#    18068,
#    578590,
#    188665,
#    592397,
#    23677,
#    123200,
#    645840,
#    311988,
#    417766,
#    626279,
#    580388,
#    400650,
#    488253,
#    572954,
#    338447,
#    226090,
#    127657,
#    602838,
#    595911,
#    650569,
#    510157,
#    460815,
#    318175,
#    313023,
#    648134,
#    486899,
#    332076,
#    122535,
#    199528,
#    463506,
#    447207,
#    424947,
#    259303,
#    475559,
#    296709,
#    669372,
#    242594,
#    705504],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 64105,
#   'songs': [570100,
#    638658,
#    659709,
#    294878,
#    41814,
#    688244,
#    504619,
#    72150,
#    74584,
#    279768,
#    68865,
#    244481,
#    505211,
#    86534,
#    666857,
#    90703,
#    403276,
#    631497,
#    248626,
#    230944,
#    618448,
#    407548,
#    456363,
#    327419,
#    466369,
#    50364,
#    336072,
#    100989,
#    19670,
#    656031,
#    294919,
#    429292,
#    544226,
#    160518,
#    464449,
#    687196,
#    416531,
#    192545,
#    156514,
#    339581,
#    113327,
#    164164,
#    650987,
#    310321,
#    265121,
#    230622,
#    656878,
#    179018,
#    26500,
#    585238,
#    204786,
#    428101,
#    469206,
#    514766,
#    505209,
#    431974,
#    146098,
#    62292,
#    28223,
#    539056,
#    345368,
#    351070,
#    275008,
#    201378,
#    503953,
#    288808,
#    593590,
#    276522,
#    53033,
#    459955,
#    254827,
#    390956,
#    73017,
#    394303,
#    266114,
#    307500,
#    396620,
#    544444,
#    490742,
#    611671,
#    3293,
#    393716,
#    209141,
#    415916,
#    429772,
#    459937,
#    518929,
#    608872,
#    699564,
#    407110,
#    414771,
#    395415,
#    137324,
#    696090,
#    587242,
#    173209,
#    591195,
#    475404,
#    48028,
#    193923],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 40637,
#   'songs': [497110,
#    157055,
#    91075,
#    516707,
#    227954,
#    621967,
#    291614,
#    670814,
#    68348,
#    486551,
#    695653,
#    265174,
#    603177,
#    21105,
#    590513,
#    136326,
#    63242,
#    578635,
#    573099,
#    669866,
#    565250,
#    113443,
#    531333,
#    449454,
#    245920,
#    523521,
#    48963,
#    3858,
#    311824,
#    541943,
#    159757,
#    588409,
#    187047,
#    289117,
#    578283,
#    600815,
#    341513,
#    164067,
#    621927,
#    263273,
#    487911,
#    563892,
#    442014,
#    42155,
#    609766,
#    38261,
#    478048,
#    259368,
#    185736,
#    669039,
#    673796,
#    448116,
#    703192,
#    254958,
#    105140,
#    612343,
#    179084,
#    110027,
#    85845,
#    509091,
#    232434,
#    582252,
#    149205,
#    354004,
#    483182,
#    676309,
#    67475,
#    490970,
#    199262,
#    207178,
#    211964,
#    683564,
#    137720,
#    433037,
#    578321,
#    677437,
#    349492,
#    394952,
#    301221,
#    287351,
#    441656,
#    176093,
#    188660,
#    176905,
#    209993,
#    15318,
#    662801,
#    498752,
#    396828,
#    435140,
#    362592,
#    509998,
#    511905,
#    591045,
#    485155,
#    521525,
#    410591,
#    667299,
#    668128,
#    552882],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 41828,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 2380,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 87846,
#   'songs': [540972,
#    44594,
#    16513,
#    297719,
#    7749,
#    640696,
#    480666,
#    613954,
#    611371,
#    685499,
#    609680,
#    366889,
#    473679,
#    281649,
#    79877,
#    426060,
#    140241,
#    382218,
#    575422,
#    234174,
#    405081,
#    54600,
#    523173,
#    480149,
#    440033,
#    462623,
#    543606,
#    455570,
#    590667,
#    71629,
#    76508,
#    546654,
#    332908,
#    602022,
#    307395,
#    400444,
#    298586,
#    457320,
#    413855,
#    553705,
#    461566,
#    563458,
#    562866,
#    424222,
#    444446,
#    57288,
#    259748,
#    499163,
#    474475,
#    491,
#    669062,
#    437117,
#    679641,
#    90754,
#    377021,
#    47374,
#    43320,
#    663802,
#    657574,
#    691333,
#    591244,
#    5742,
#    299954,
#    390531,
#    183344,
#    11762,
#    451489,
#    81559,
#    463413,
#    542882,
#    166950,
#    571027,
#    597185,
#    233478,
#    435281,
#    236244,
#    669540,
#    40190,
#    598035,
#    407235,
#    233772,
#    177620,
#    297949,
#    225884,
#    261610,
#    85946,
#    12841,
#    90213,
#    624540,
#    463611,
#    564439,
#    151347,
#    146464,
#    352215,
#    625994,
#    424810,
#    193112,
#    462664,
#    530892,
#    236814],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 94446,
#   'songs': [298446,
#    512079,
#    514323,
#    549720,
#    461463,
#    550426,
#    53258,
#    526781,
#    617593,
#    482423,
#    505898,
#    45120,
#    377143,
#    84059,
#    556635,
#    64404,
#    639188,
#    287227,
#    413510,
#    330589,
#    605658,
#    464764,
#    689788,
#    61849,
#    643013,
#    483201,
#    628396,
#    347867,
#    18714,
#    176010,
#    702437,
#    456156,
#    56008,
#    588791,
#    89756,
#    402771,
#    269078,
#    700489,
#    550440,
#    326424,
#    388262,
#    564479,
#    398263,
#    598585,
#    306631,
#    215806,
#    698833,
#    155030,
#    613088,
#    161708,
#    33152,
#    275923,
#    591971,
#    59501,
#    660963,
#    475033,
#    218110,
#    636183,
#    666402,
#    241015,
#    170614,
#    495945,
#    263273,
#    525522,
#    14064,
#    165549,
#    83875,
#    47484,
#    29143,
#    288409,
#    650695,
#    250345,
#    533578,
#    56977,
#    567861,
#    484500,
#    207073,
#    144785,
#    581823,
#    500278,
#    603976,
#    191890,
#    249056,
#    155938,
#    262504,
#    5554,
#    178752,
#    174247,
#    257998,
#    131295,
#    203322,
#    253242,
#    360137,
#    422241,
#    210432,
#    176000,
#    264652,
#    90587,
#    366859,
#    328222],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 149069,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 7373,
#   'songs': [302648,
#    253259,
#    360010,
#    369998,
#    324437,
#    489590,
#    307644,
#    233844,
#    113623,
#    294395,
#    136972,
#    512375,
#    44443,
#    448920,
#    371902,
#    128474,
#    640699,
#    677181,
#    363883,
#    43211,
#    599173,
#    398446,
#    267809,
#    177569,
#    459741,
#    362763,
#    88368,
#    567794,
#    99440,
#    391721,
#    229798,
#    498514,
#    357079,
#    555140,
#    542189,
#    498496,
#    345367,
#    382222,
#    108601,
#    140339,
#    452923,
#    578394,
#    694084,
#    463883,
#    399190,
#    332275,
#    411658,
#    127822,
#    214795,
#    430803,
#    616629,
#    247056,
#    95180,
#    298640,
#    251544,
#    69752,
#    113177,
#    114649,
#    47154,
#    583079,
#    653927,
#    330529,
#    2463,
#    676757,
#    391308,
#    578407,
#    275012,
#    634404,
#    255940,
#    12729,
#    393128,
#    297925,
#    469872,
#    322837,
#    632219,
#    338416,
#    692878,
#    39264,
#    41582,
#    506851,
#    91354,
#    149940,
#    599714,
#    1446,
#    382205,
#    68591,
#    688325,
#    344511,
#    398974,
#    450358,
#    664547,
#    62530,
#    232994,
#    521164,
#    697499,
#    604029,
#    696158,
#    608903,
#    562238,
#    234751],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 74934,
#   'songs': [529377,
#    489027,
#    379347,
#    693770,
#    666451,
#    163383,
#    107755,
#    205976,
#    626751,
#    674022,
#    395991,
#    267545,
#    423018,
#    522729,
#    574990,
#    532492,
#    102122,
#    266865,
#    611883,
#    372434,
#    668200,
#    371720,
#    519741,
#    568617,
#    465337,
#    551542,
#    10467,
#    509301,
#    359733,
#    171353,
#    313165,
#    287532,
#    446552,
#    655407,
#    54931,
#    630877,
#    540263,
#    317429,
#    680078,
#    695202,
#    333816,
#    621756,
#    354821,
#    152782,
#    335448,
#    191553,
#    41811,
#    110818,
#    299365,
#    306220,
#    611121,
#    635315,
#    87411,
#    646753,
#    562996,
#    303870,
#    303505,
#    652484,
#    679588,
#    366692,
#    212266,
#    661054,
#    475641,
#    316947,
#    5435,
#    21091,
#    690566,
#    258508,
#    90076,
#    71306,
#    611137,
#    566829,
#    614361,
#    8782,
#    93988,
#    544745,
#    246743,
#    345949,
#    485265,
#    382252,
#    503435,
#    696854,
#    75848,
#    131214,
#    11011,
#    220351,
#    464802,
#    231393,
#    122453,
#    630403,
#    275337,
#    337349,
#    587173,
#    270237,
#    644019,
#    32592,
#    561655,
#    588605,
#    463060,
#    237503],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 29647,
#   'songs': [290849,
#    423294,
#    72359,
#    232129,
#    610298,
#    31469,
#    253370,
#    197145,
#    293139,
#    109541,
#    371075,
#    460682,
#    220603,
#    289949,
#    107892,
#    118715,
#    152820,
#    274143,
#    230847,
#    391112,
#    168834,
#    80977,
#    690911,
#    638714,
#    290473,
#    562034,
#    124116,
#    151965,
#    100335,
#    451229,
#    516218,
#    119514,
#    27541,
#    524447,
#    12981,
#    208867,
#    656054,
#    283397,
#    389366,
#    17642,
#    700409,
#    440833,
#    535901,
#    580433,
#    149384,
#    17699,
#    460964,
#    661246,
#    172121,
#    478112,
#    565379,
#    570986,
#    362743,
#    165424,
#    389503,
#    383912,
#    301358,
#    163963,
#    86685,
#    585596,
#    201154,
#    443335,
#    415738,
#    358117,
#    571102,
#    134315,
#    90448,
#    250558,
#    170563,
#    350459,
#    519827,
#    72476,
#    325120,
#    48321,
#    21751,
#    554657,
#    324136,
#    321907,
#    19172,
#    40800,
#    500163,
#    525281,
#    535650,
#    545824,
#    619652,
#    308281,
#    378978,
#    352123,
#    226627,
#    410487,
#    380110,
#    192823,
#    688851,
#    396046,
#    220043,
#    646926,
#    470617,
#    610046,
#    508045,
#    94912],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 105642,
#   'songs': [245284,
#    386957,
#    216430,
#    173304,
#    463636,
#    49644,
#    250273,
#    667584,
#    662869,
#    454611,
#    617901,
#    313402,
#    437539,
#    222373,
#    209845,
#    309999,
#    6453,
#    257420,
#    475475,
#    656517,
#    175073,
#    395033,
#    251025,
#    184481,
#    454512,
#    266529,
#    627932,
#    76538,
#    478510,
#    90961,
#    605802,
#    664253,
#    524399,
#    697939,
#    386053,
#    46836,
#    312466,
#    350491,
#    402439,
#    498530,
#    522650,
#    691325,
#    101583,
#    296042,
#    423194,
#    488078,
#    44113,
#    116573,
#    501713,
#    274601,
#    388330,
#    56394,
#    156216,
#    612468,
#    411215,
#    76141,
#    527261,
#    331690,
#    4725,
#    461732,
#    26361,
#    144302,
#    628231,
#    331390,
#    494057,
#    504360,
#    50951,
#    430334,
#    108482,
#    113622,
#    476826,
#    188235,
#    320952,
#    513583,
#    46437,
#    703348,
#    411745,
#    621515,
#    419121,
#    169897,
#    226385,
#    127384,
#    598860,
#    575036,
#    24363,
#    529263,
#    3395,
#    80506,
#    677137,
#    315508,
#    267683,
#    551064,
#    236841,
#    683700,
#    547868,
#    299198,
#    38765,
#    528636,
#    598029,
#    114247],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 41619,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 150267,
#   'songs': [183636,
#    453493,
#    320551,
#    186353,
#    186067,
#    492141,
#    51576,
#    359029,
#    10408,
#    561656,
#    97184,
#    236964,
#    208501,
#    61951,
#    38069,
#    384396,
#    191393,
#    41702,
#    261817,
#    591517,
#    658754,
#    654386,
#    915,
#    74371,
#    336102,
#    72298,
#    78972,
#    540183,
#    87412,
#    643089,
#    39796,
#    101583,
#    82079,
#    596036,
#    655751,
#    608674,
#    9275,
#    509593,
#    283034,
#    54812,
#    639411,
#    114470,
#    640751,
#    207824,
#    327899,
#    580870,
#    207242,
#    178098,
#    188107,
#    536477,
#    116229,
#    217905,
#    530296,
#    177966,
#    188474,
#    179903,
#    425788,
#    485965,
#    572690,
#    12836,
#    302145,
#    610398,
#    368103,
#    62727,
#    684650,
#    532108,
#    275908,
#    259524,
#    575641,
#    138504,
#    11318,
#    302475,
#    295388,
#    26146,
#    654463,
#    174406,
#    313079,
#    227850,
#    101386,
#    691550,
#    228125,
#    431423,
#    642379,
#    183397,
#    487259,
#    37319,
#    535609,
#    141091,
#    240604,
#    301981,
#    238154,
#    528525,
#    693933,
#    22230,
#    660778,
#    418001,
#    660950,
#    238425,
#    611067,
#    317387],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 65872,
#   'songs': [429404,
#    634743,
#    232773,
#    550389,
#    18368,
#    136088,
#    23914,
#    537983,
#    89446,
#    163250,
#    285726,
#    202448,
#    117852,
#    161253,
#    442601,
#    77010,
#    387307,
#    422008,
#    177128,
#    212832,
#    26855,
#    277885,
#    645059,
#    40137,
#    596005,
#    372173,
#    680099,
#    569851,
#    568710,
#    297320,
#    408635,
#    38477,
#    405166,
#    302920,
#    54657,
#    271529,
#    302881,
#    324580,
#    474208,
#    479584,
#    160291,
#    241608,
#    605399,
#    98315,
#    108406,
#    483237,
#    445550,
#    381885,
#    229834,
#    62864,
#    352675,
#    213127,
#    106132,
#    383520,
#    130310,
#    11267,
#    641157,
#    286973,
#    314732,
#    510979,
#    85726,
#    289435,
#    358462,
#    677691,
#    391188,
#    349465,
#    200687,
#    224410,
#    194469,
#    130268,
#    15171,
#    199831,
#    184839,
#    477304,
#    96506,
#    403243,
#    53132,
#    147693,
#    51929,
#    380859,
#    329263,
#    108034,
#    218360,
#    492637,
#    535248,
#    536293,
#    413243,
#    106537,
#    12829,
#    690079,
#    39608,
#    297457,
#    573283,
#    193379,
#    255360,
#    214457,
#    292192,
#    312404,
#    625554,
#    93042],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 93962,
#   'songs': [134155,
#    560678,
#    168320,
#    425558,
#    700488,
#    134941,
#    73953,
#    74588,
#    606773,
#    224484,
#    667203,
#    394561,
#    85481,
#    343829,
#    371247,
#    298799,
#    73912,
#    558938,
#    620057,
#    587652,
#    150571,
#    160512,
#    416646,
#    540926,
#    157071,
#    592431,
#    688028,
#    570429,
#    221066,
#    388180,
#    610588,
#    234404,
#    668020,
#    200761,
#    325737,
#    575603,
#    428449,
#    646573,
#    350369,
#    225082,
#    635330,
#    528024,
#    458053,
#    410772,
#    43163,
#    518484,
#    464686,
#    578277,
#    87208,
#    652748,
#    363170,
#    128057,
#    317261,
#    203791,
#    261453,
#    543432,
#    291096,
#    55101,
#    47587,
#    395056,
#    113521,
#    491593,
#    275239,
#    432957,
#    274463,
#    377436,
#    659150,
#    331572,
#    175514,
#    102942,
#    46638,
#    62421,
#    669736,
#    288118,
#    437953,
#    440101,
#    30288,
#    624332,
#    570969,
#    680027,
#    63957,
#    583916,
#    289091,
#    190703,
#    140051,
#    409432,
#    262551,
#    685867,
#    288958,
#    689262,
#    126199,
#    641909,
#    566234,
#    179973,
#    230549,
#    132985,
#    676856,
#    547864,
#    302975,
#    706647],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 100937,
#   'songs': [377622,
#    694295,
#    169945,
#    288044,
#    371942,
#    595323,
#    226675,
#    198288,
#    628809,
#    396820,
#    394741,
#    409151,
#    215244,
#    614424,
#    673473,
#    520275,
#    618087,
#    607251,
#    50318,
#    676251,
#    117942,
#    260077,
#    647822,
#    504681,
#    203210,
#    459908,
#    278579,
#    486558,
#    633247,
#    72298,
#    629201,
#    183909,
#    512107,
#    690826,
#    691485,
#    549480,
#    675906,
#    286694,
#    201602,
#    149750,
#    170838,
#    419658,
#    112525,
#    218266,
#    230610,
#    416951,
#    270470,
#    159491,
#    66661,
#    311287,
#    514167,
#    596246,
#    492484,
#    287641,
#    557900,
#    8706,
#    205139,
#    119757,
#    284395,
#    248989,
#    90959,
#    561220,
#    205522,
#    637303,
#    119885,
#    434659,
#    225240,
#    271752,
#    18353,
#    196609,
#    363127,
#    536335,
#    238644,
#    285508,
#    31168,
#    660481,
#    666626,
#    446419,
#    151218,
#    693431,
#    587121,
#    289207,
#    193829,
#    444938,
#    130065,
#    702738,
#    292997,
#    323077,
#    217771,
#    117470,
#    142881,
#    91779,
#    128085,
#    551031,
#    144486,
#    140231,
#    108605,
#    617595,
#    477056,
#    49301],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 1531,
#   'songs': [338660,
#    140504,
#    219865,
#    368417,
#    261495,
#    254792,
#    682764,
#    389750,
#    4975,
#    465194,
#    470199,
#    307318,
#    559514,
#    179330,
#    587668,
#    153824,
#    63820,
#    510530,
#    186453,
#    659297,
#    274645,
#    605990,
#    641276,
#    119703,
#    409100,
#    502971,
#    73193,
#    573103,
#    437677,
#    505219,
#    603899,
#    443390,
#    310737,
#    256658,
#    237808,
#    338022,
#    32096,
#    598590,
#    259526,
#    681719,
#    395742,
#    598147,
#    69364,
#    559102,
#    551459,
#    378456,
#    4662,
#    329521,
#    579732,
#    696238,
#    415189,
#    552725,
#    196480,
#    199127,
#    323277,
#    527887,
#    372117,
#    116281,
#    647778,
#    452737,
#    407154,
#    622645,
#    685395,
#    399489,
#    306683,
#    686657,
#    581658,
#    537611,
#    472495,
#    615352,
#    295661,
#    286653,
#    589083,
#    4672,
#    514830,
#    38393,
#    78621,
#    10622,
#    369417,
#    424825,
#    164409,
#    572589,
#    474374,
#    1088,
#    637790,
#    110275,
#    345014,
#    363045,
#    643558,
#    596935,
#    171383,
#    179899,
#    644138,
#    139396,
#    379165,
#    298009,
#    155366,
#    477538,
#    364030,
#    86974],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 25889,
#   'songs': [73324,
#    450170,
#    600116,
#    563956,
#    315654,
#    400635,
#    531264,
#    187073,
#    198346,
#    93809,
#    283002,
#    344076,
#    465827,
#    680747,
#    196166,
#    545855,
#    524475,
#    515880,
#    322963,
#    234410,
#    461210,
#    389591,
#    20084,
#    557549,
#    33686,
#    40396,
#    477182,
#    415799,
#    700105,
#    93541,
#    210967,
#    638147,
#    214514,
#    58289,
#    433069,
#    47868,
#    212764,
#    408939,
#    371013,
#    496127,
#    412861,
#    378883,
#    619563,
#    358420,
#    301959,
#    690852,
#    523788,
#    418699,
#    673358,
#    652893,
#    111597,
#    621079,
#    579419,
#    99737,
#    299972,
#    284763,
#    207036,
#    125919,
#    666354,
#    540253,
#    528671,
#    524535,
#    78458,
#    546790,
#    5060,
#    526833,
#    433460,
#    645618,
#    494131,
#    223384,
#    350866,
#    298949,
#    693511,
#    69838,
#    607792,
#    229675,
#    678908,
#    399918,
#    90597,
#    546767,
#    76438,
#    362016,
#    22657,
#    328622,
#    236424,
#    271376,
#    404122,
#    347999,
#    475032,
#    624971,
#    211460,
#    205507,
#    436580,
#    110769,
#    579788,
#    216448,
#    635060,
#    423933,
#    95721,
#    3884],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 67644,
#   'songs': [524168,
#    273063,
#    302917,
#    352733,
#    128882,
#    358002,
#    363967,
#    373287,
#    38868,
#    334961,
#    304144,
#    701694,
#    689167,
#    670425,
#    114175,
#    73224,
#    110149,
#    190402,
#    333579,
#    162149,
#    462997,
#    238062,
#    635962,
#    455668,
#    153634,
#    453,
#    263453,
#    221651,
#    31597,
#    45180,
#    30552,
#    271924,
#    481987,
#    585221,
#    548055,
#    637787,
#    211120,
#    390960,
#    299210,
#    372770,
#    114894,
#    549138,
#    1004,
#    76992,
#    399897,
#    124922,
#    476310,
#    42753,
#    548432,
#    674497,
#    329084,
#    281173,
#    651036,
#    421442,
#    282750,
#    76727,
#    216466,
#    375764,
#    69665,
#    509030,
#    689177,
#    212104,
#    573762,
#    313979,
#    463104,
#    61346,
#    150116,
#    560650,
#    153977,
#    178784,
#    299231,
#    480920,
#    379007,
#    270855,
#    1628,
#    431965,
#    419595,
#    321914,
#    153333,
#    215618,
#    418220,
#    378663,
#    338585,
#    404774,
#    110914,
#    344536,
#    385438,
#    84627,
#    226745,
#    165020,
#    655701,
#    46488,
#    202826,
#    514745,
#    445334,
#    173285,
#    121876,
#    23911,
#    309288,
#    524643],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 122267,
#   'songs': [628499,
#    238476,
#    489027,
#    400340,
#    284875,
#    145895,
#    692572,
#    693827,
#    337000,
#    27346,
#    213483,
#    143660,
#    532771,
#    433145,
#    95445,
#    572075,
#    147132,
#    600070,
#    421813,
#    689010,
#    317765,
#    56175,
#    525011,
#    42160,
#    79323,
#    416876,
#    209096,
#    53533,
#    453761,
#    583419,
#    242527,
#    530669,
#    216093,
#    219240,
#    668840,
#    32990,
#    545619,
#    140843,
#    325453,
#    186889,
#    701979,
#    165921,
#    659944,
#    13536,
#    219475,
#    254085,
#    283694,
#    121165,
#    200974,
#    598590,
#    597257,
#    679136,
#    318475,
#    27363,
#    430167,
#    533316,
#    242649,
#    580350,
#    144723,
#    185329,
#    82472,
#    23866,
#    249755,
#    397380,
#    697827,
#    234040,
#    699033,
#    77432,
#    512833,
#    45254,
#    181328,
#    339249,
#    604649,
#    429017,
#    191886,
#    185929,
#    397989,
#    259938,
#    694241,
#    108570,
#    200291,
#    284608,
#    410247,
#    679743,
#    98372,
#    10288,
#    326625,
#    550893,
#    282112,
#    518717,
#    350397,
#    391823,
#    127720,
#    238595,
#    624717,
#    588413,
#    98331,
#    350048,
#    626131,
#    632860],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 79847,
#   'songs': [514941,
#    16826,
#    232491,
#    584124,
#    573148,
#    556260,
#    477327,
#    361253,
#    636119,
#    180725,
#    359029,
#    162580,
#    24046,
#    449980,
#    621431,
#    233817,
#    543186,
#    127045,
#    589220,
#    47027,
#    217224,
#    167012,
#    376401,
#    652299,
#    636092,
#    158377,
#    264492,
#    707602,
#    458506,
#    571688,
#    672150,
#    648973,
#    205684,
#    20617,
#    516422,
#    60724,
#    604339,
#    680492,
#    660559,
#    228262,
#    46327,
#    285515,
#    65122,
#    246990,
#    330985,
#    324550,
#    455019,
#    705759,
#    555134,
#    671605,
#    283796,
#    378112,
#    115930,
#    563513,
#    23687,
#    69665,
#    210073,
#    443659,
#    300170,
#    194471,
#    248020,
#    49360,
#    353692,
#    65762,
#    546368,
#    69084,
#    678514,
#    154699,
#    379108,
#    186312,
#    681799,
#    407738,
#    115375,
#    552787,
#    8114,
#    334965,
#    4464,
#    278004,
#    126363,
#    262878,
#    609922,
#    556320,
#    9086,
#    567806,
#    341719,
#    562409,
#    193066,
#    344250,
#    690229,
#    703632,
#    373916,
#    198626,
#    332866,
#    174179,
#    508736,
#    235369,
#    325140,
#    455774,
#    28373,
#    120630],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 65114,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 113276,
#   'songs': [36257,
#    21273,
#    197889,
#    1816,
#    464511,
#    54798,
#    351653,
#    190856,
#    472707,
#    605972,
#    336888,
#    297821,
#    640807,
#    200100,
#    43565,
#    508176,
#    277624,
#    455756,
#    561515,
#    57605,
#    204905,
#    674333,
#    517861,
#    702445,
#    33107,
#    80788,
#    108382,
#    398271,
#    386175,
#    424095,
#    634299,
#    646604,
#    488231,
#    386423,
#    661999,
#    676731,
#    66936,
#    20007,
#    353158,
#    413800,
#    583224,
#    231814,
#    10269,
#    595458,
#    535088,
#    24561,
#    306523,
#    605434,
#    444394,
#    432567,
#    671214,
#    594491,
#    545636,
#    345230,
#    207358,
#    100358,
#    38389,
#    28037,
#    572831,
#    74066,
#    421719,
#    519392,
#    472394,
#    247683,
#    403356,
#    566498,
#    40462,
#    204611,
#    313090,
#    49046,
#    536657,
#    556827,
#    461420,
#    47487,
#    516100,
#    116044,
#    312388,
#    29075,
#    406166,
#    520142,
#    607355,
#    633745,
#    383912,
#    298277,
#    240953,
#    281533,
#    197565,
#    265265,
#    608902,
#    658535,
#    481576,
#    161264,
#    620219,
#    284475,
#    352720,
#    633586,
#    634933,
#    556232,
#    389614,
#    265743],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 110642,
#   'songs': [578649,
#    603631,
#    148862,
#    501949,
#    634056,
#    110415,
#    489430,
#    495248,
#    402736,
#    308023,
#    467116,
#    435340,
#    561142,
#    264961,
#    331589,
#    508030,
#    269161,
#    230842,
#    137890,
#    511657,
#    313725,
#    135549,
#    649723,
#    704867,
#    64641,
#    336946,
#    105388,
#    263485,
#    263129,
#    541300,
#    420041,
#    295069,
#    179597,
#    289420,
#    215523,
#    250582,
#    277102,
#    159479,
#    23057,
#    120601,
#    174208,
#    256073,
#    602306,
#    341258,
#    87412,
#    307562,
#    682047,
#    692159,
#    73670,
#    393958,
#    439011,
#    502265,
#    703624,
#    204470,
#    605691,
#    349793,
#    129825,
#    374397,
#    431309,
#    195246,
#    331846,
#    402574,
#    646072,
#    417021,
#    391662,
#    465892,
#    372794,
#    601175,
#    220367,
#    393453,
#    110985,
#    86627,
#    458638,
#    115050,
#    99014,
#    700241,
#    437705,
#    167745,
#    271688,
#    569941,
#    324122,
#    253519,
#    365265,
#    635610,
#    33180,
#    275198,
#    452528,
#    538070,
#    1776,
#    532064,
#    199869,
#    256255,
#    108573,
#    364806,
#    45461,
#    309082,
#    571057,
#    366144,
#    393456,
#    309789],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 147722,
#   'songs': [311663,
#    158951,
#    616166,
#    185406,
#    633627,
#    597758,
#    162752,
#    402531,
#    453239,
#    389001,
#    172352,
#    561085,
#    307177,
#    10103,
#    56651,
#    315550,
#    620080,
#    294046,
#    408928,
#    416646,
#    41463,
#    654191,
#    675547,
#    563425,
#    325054,
#    10960,
#    149465,
#    592117,
#    384650,
#    1755,
#    52928,
#    647371,
#    602575,
#    373213,
#    363437,
#    507622,
#    297664,
#    286116,
#    390538,
#    351614,
#    528589,
#    108260,
#    569880,
#    179362,
#    163968,
#    190833,
#    100398,
#    255100,
#    607599,
#    587114,
#    514064,
#    694540,
#    419734,
#    657137,
#    304363,
#    49056,
#    705741,
#    629112,
#    127791,
#    78521,
#    292731,
#    685437,
#    157327,
#    344248,
#    114697,
#    438240,
#    212924,
#    221061,
#    644998,
#    680836,
#    98665,
#    143492,
#    535659,
#    45953,
#    310892,
#    567698,
#    241751,
#    299388,
#    379558,
#    81703,
#    439272,
#    17806,
#    256085,
#    277170,
#    260261,
#    433841,
#    276712,
#    681083,
#    322370,
#    113386,
#    376916,
#    276435,
#    212426,
#    59254,
#    58169,
#    221266,
#    477228,
#    35790,
#    663739,
#    271988],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 27612,
#   'songs': [84157,
#    109701,
#    250570,
#    124664,
#    509878,
#    483287,
#    223351,
#    470392,
#    296211,
#    557495,
#    385387,
#    350908,
#    480956,
#    534705,
#    420914,
#    662170,
#    41813,
#    502886,
#    267022,
#    616879,
#    439035,
#    673052,
#    88530,
#    246901,
#    2232,
#    298024,
#    104248,
#    694211,
#    156659,
#    641197,
#    304375,
#    74921,
#    531098,
#    393302,
#    275379,
#    317677,
#    512855,
#    654535,
#    278061,
#    520980,
#    494154,
#    579826,
#    497526,
#    532990,
#    681010,
#    73212,
#    90634,
#    292543,
#    136995,
#    158604,
#    465226,
#    60290,
#    302262,
#    593726,
#    421475,
#    306448,
#    113622,
#    474937,
#    397752,
#    546790,
#    272248,
#    436254,
#    23835,
#    288083,
#    471077,
#    648197,
#    478236,
#    373551,
#    87478,
#    631031,
#    667864,
#    30327,
#    620663,
#    273724,
#    195951,
#    264018,
#    436013,
#    240995,
#    202142,
#    344457,
#    486100,
#    633227,
#    537943,
#    433242,
#    524417,
#    191535,
#    340315,
#    183240,
#    364226,
#    424062,
#    254144,
#    557551,
#    168750,
#    18889,
#    268886,
#    187049,
#    550301,
#    190482,
#    249758,
#    591516],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 80682,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 65063,
#   'songs': [111675,
#    368618,
#    257363,
#    692727,
#    130933,
#    565588,
#    501621,
#    159454,
#    12628,
#    245228,
#    49794,
#    472973,
#    85920,
#    212472,
#    707398,
#    520898,
#    140678,
#    2500,
#    301304,
#    704070,
#    78102,
#    340222,
#    47912,
#    58585,
#    3657,
#    298257,
#    358118,
#    516838,
#    302527,
#    593235,
#    333033,
#    412615,
#    539252,
#    410120,
#    523690,
#    236939,
#    372755,
#    659527,
#    58271,
#    249683,
#    554751,
#    182365,
#    420905,
#    447717,
#    571657,
#    529369,
#    640012,
#    605892,
#    658150,
#    557357,
#    494057,
#    78221,
#    598843,
#    497407,
#    523058,
#    261337,
#    461580,
#    227291,
#    175947,
#    125863,
#    346931,
#    574861,
#    557159,
#    163153,
#    539804,
#    371472,
#    172225,
#    359371,
#    456476,
#    448982,
#    462044,
#    585751,
#    111289,
#    79271,
#    240968,
#    451841,
#    149551,
#    481335,
#    42525,
#    251066,
#    696645,
#    253163,
#    605529,
#    371893,
#    359929,
#    470871,
#    91779,
#    670915,
#    49610,
#    110249,
#    638165,
#    512661,
#    93916,
#    354984,
#    176984,
#    335522,
#    385343,
#    499347,
#    304481,
#    494944],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 8253,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 118572,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 5240,
#   'songs': [468107,
#    415367,
#    431570,
#    542248,
#    42323,
#    363685,
#    61277,
#    156734,
#    175020,
#    572466,
#    101227,
#    47450,
#    89052,
#    165592,
#    498310,
#    312737,
#    504341,
#    480948,
#    344371,
#    430532,
#    658147,
#    225137,
#    535466,
#    379145,
#    286874,
#    336072,
#    679791,
#    232583,
#    82061,
#    469950,
#    438074,
#    272007,
#    526330,
#    511028,
#    642502,
#    251868,
#    242941,
#    31217,
#    315986,
#    623569,
#    116939,
#    101557,
#    303189,
#    357499,
#    405277,
#    99760,
#    492634,
#    321810,
#    427953,
#    659264,
#    612938,
#    576513,
#    702312,
#    66434,
#    116451,
#    619464,
#    159849,
#    604688,
#    324705,
#    616737,
#    468755,
#    268998,
#    90585,
#    378399,
#    267407,
#    72871,
#    337076,
#    182847,
#    332882,
#    256436,
#    582287,
#    222597,
#    202919,
#    517817,
#    21746,
#    609252,
#    316497,
#    543176,
#    301899,
#    644373,
#    224143,
#    377494,
#    691198,
#    617916,
#    70049,
#    43823,
#    589815,
#    163924,
#    349451,
#    330386,
#    551504,
#    174485,
#    177917,
#    490385,
#    677846,
#    677431,
#    484788,
#    131193,
#    483663,
#    149060],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 81994,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 33151,
#   'songs': [406976,
#    82712,
#    139576,
#    378972,
#    414916,
#    247756,
#    196531,
#    278452,
#    86149,
#    413667,
#    308157,
#    596723,
#    202379,
#    673210,
#    77263,
#    383916,
#    36971,
#    501764,
#    417565,
#    610551,
#    407456,
#    252834,
#    578918,
#    524927,
#    312325,
#    487362,
#    678762,
#    198986,
#    27784,
#    538982,
#    440559,
#    480555,
#    98918,
#    521760,
#    139879,
#    148266,
#    40587,
#    328448,
#    671109,
#    336013,
#    92652,
#    360925,
#    172046,
#    350309,
#    652367,
#    118639,
#    401259,
#    513781,
#    335637,
#    9467,
#    570872,
#    519638,
#    236289,
#    555295,
#    348464,
#    14855,
#    151620,
#    401082,
#    487655,
#    611741,
#    467913,
#    51551,
#    534085,
#    546867,
#    660333,
#    535347,
#    195652,
#    572805,
#    562393,
#    110456,
#    407618,
#    102206,
#    194464,
#    29875,
#    440799,
#    651815,
#    267233,
#    284184,
#    628780,
#    108932,
#    394528,
#    557056,
#    117039,
#    278571,
#    422873,
#    182678,
#    551764,
#    96135,
#    186284,
#    615493,
#    675910,
#    157827,
#    150276,
#    321187,
#    329884,
#    200540,
#    142176,
#    77723,
#    532677,
#    211786],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 69966,
#   'songs': [144789,
#    64885,
#    249945,
#    403954,
#    408983,
#    484365,
#    27744,
#    297467,
#    72930,
#    80574,
#    34384,
#    160808,
#    553250,
#    678511,
#    578768,
#    634530,
#    424219,
#    506874,
#    266299,
#    174980,
#    288937,
#    614195,
#    372594,
#    388378,
#    203916,
#    20598,
#    36312,
#    354465,
#    408775,
#    482409,
#    707788,
#    666466,
#    100211,
#    616065,
#    211456,
#    229220,
#    569439,
#    665754,
#    74252,
#    377244,
#    361384,
#    280169,
#    48148,
#    301881,
#    336835,
#    114404,
#    206131,
#    253398,
#    55528,
#    625885,
#    278323,
#    9514,
#    380313,
#    670271,
#    499304,
#    198594,
#    64155,
#    385917,
#    678358,
#    704267,
#    44671,
#    455734,
#    631439,
#    653535,
#    193101,
#    262902,
#    534040,
#    113065,
#    167849,
#    190335,
#    298914,
#    689235,
#    227131,
#    499911,
#    142016,
#    652072,
#    537517,
#    46295,
#    40033,
#    89318,
#    122620,
#    187387,
#    144674,
#    206668,
#    489799,
#    647849,
#    187484,
#    300561,
#    693004,
#    629389,
#    582924,
#    613922,
#    373933,
#    549912,
#    303023,
#    514679,
#    215072,
#    348207,
#    482622,
#    690092],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 63145,
#   'songs': [418039,
#    385603,
#    355651,
#    323067,
#    434817,
#    199370,
#    470392,
#    423203,
#    621431,
#    38509,
#    569548,
#    30430,
#    296211,
#    425148,
#    10034,
#    374924,
#    137456,
#    41813,
#    424,
#    374537,
#    227328,
#    168837,
#    246901,
#    110899,
#    252483,
#    648514,
#    423456,
#    143504,
#    328898,
#    440294,
#    457016,
#    100335,
#    74921,
#    693543,
#    325143,
#    625126,
#    150034,
#    483763,
#    8013,
#    275379,
#    512855,
#    473843,
#    268475,
#    423649,
#    450838,
#    520980,
#    36118,
#    70126,
#    421981,
#    74463,
#    671627,
#    542474,
#    59480,
#    511979,
#    673766,
#    448092,
#    66491,
#    188936,
#    605854,
#    248565,
#    152366,
#    534054,
#    194755,
#    593726,
#    239646,
#    368238,
#    155912,
#    429950,
#    579943,
#    631528,
#    237094,
#    95725,
#    221430,
#    589217,
#    68528,
#    473029,
#    137626,
#    55908,
#    398329,
#    653281,
#    191535,
#    15341,
#    476416,
#    177477,
#    326568,
#    470810,
#    675754,
#    244550,
#    698240,
#    6606,
#    674707,
#    329205,
#    30311,
#    553522,
#    484152,
#    660180,
#    598971,
#    288591,
#    206983,
#    645223],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 41512,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 101739,
#   'songs': [234031,
#    380952,
#    423348,
#    207222,
#    328520,
#    561493,
#    318626,
#    682405,
#    24796,
#    347190,
#    647437,
#    436259,
#    699180,
#    16405,
#    216489,
#    584086,
#    119647,
#    416295,
#    55397,
#    40532,
#    115765,
#    406417,
#    482924,
#    623343,
#    166453,
#    438222,
#    140981,
#    188263,
#    126947,
#    594889,
#    394282,
#    420384,
#    429920,
#    215240,
#    165756,
#    521860,
#    486180,
#    138452,
#    100710,
#    388557,
#    507768,
#    109375,
#    112791,
#    609369,
#    246793,
#    161498,
#    287277,
#    157087,
#    35207,
#    412671,
#    590639,
#    450947,
#    278746,
#    537221,
#    158766,
#    335274,
#    289617,
#    229360,
#    425668,
#    385931,
#    575870,
#    270452,
#    337371,
#    60578,
#    634451,
#    561851,
#    97314,
#    630995,
#    427317,
#    30285,
#    23605,
#    256245,
#    368066,
#    266399,
#    212859,
#    14382,
#    484836,
#    213612,
#    410477,
#    464814,
#    234449,
#    625168,
#    591053,
#    121934,
#    286516,
#    27709,
#    348669,
#    685060,
#    518995,
#    421354,
#    419278,
#    542645,
#    600494,
#    276310,
#    513451,
#    162262,
#    23412,
#    355201,
#    96016,
#    590250],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 64189,
#   'songs': [395193,
#    11638,
#    189272,
#    120934,
#    184462,
#    368126,
#    317075,
#    108285,
#    27060,
#    579007,
#    98988,
#    241989,
#    221624,
#    442944,
#    194430,
#    362305,
#    577886,
#    386801,
#    361081,
#    600045,
#    325090,
#    422812,
#    366153,
#    109131,
#    262464,
#    122388,
#    562933,
#    303613,
#    680254,
#    390503,
#    614604,
#    2232,
#    416802,
#    662000,
#    285331,
#    158278,
#    511903,
#    281222,
#    378870,
#    198921,
#    192773,
#    20335,
#    380399,
#    153062,
#    587946,
#    461804,
#    233657,
#    259298,
#    673197,
#    664640,
#    239698,
#    79427,
#    531820,
#    647840,
#    650633,
#    429623,
#    429152,
#    299927,
#    588253,
#    321283,
#    464058,
#    516548,
#    556408,
#    387287,
#    332346,
#    544593,
#    453718,
#    131519,
#    517518,
#    114553,
#    556596,
#    382533,
#    602268,
#    395922,
#    249562,
#    272053,
#    571016,
#    535274,
#    400476,
#    73363,
#    168347,
#    175506,
#    494281,
#    120102,
#    443758,
#    378325,
#    667529,
#    492619,
#    678900,
#    17650,
#    320697,
#    504355,
#    80387,
#    254854,
#    66040,
#    543751,
#    251074,
#    308824,
#    269382,
#    364032],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 15893,
#   'songs': [213384,
#    667577,
#    707408,
#    106825,
#    135131,
#    653002,
#    703681,
#    141227,
#    214915,
#    138245,
#    71164,
#    664952,
#    95397,
#    293923,
#    233257,
#    655458,
# ...
#    185834,
#    274607,
#    511328,
#    970,
#    161348,
#    115259,
#    553744,
#    431666,
#    163000,
#    555973,
#    508573,
#    645953,
#    202570,
#    466188,
#    21865],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 48517,
#   'songs': [252220,
#    164139,
#    621851,
#    244876,
#    415472,
#    619157,
#    654225,
#    268375,
#    381227,
#    613864,
#    113232,
#    235387,
#    690077,
#    76751,
#    252620,
#    378330,
#    568224,
#    636508,
#    660522,
#    370399,
#    623172,
#    474719,
#    422807,
#    537455,
#    352772,
#    549699,
#    52767,
#    665788,
#    133875,
#    477086,
#    447174,
#    290170,
#    411300,
#    105987,
#    241152,
#    229004,
#    664140,
#    34956,
#    641053,
#    411129,
#    349691,
#    156263,
#    160160,
#    319952,
#    147140,
#    478084,
#    445358,
#    201137,
#    96202,
#    576924,
#    472398,
#    296010,
#    430139,
#    633786,
#    642683,
#    589233,
#    506749,
#    200294,
#    699987,
#    335489,
#    498950,
#    117235,
#    636346,
#    28609,
#    529671,
#    502521,
#    309497,
#    566416,
#    33508,
#    294839,
#    657579,
#    412444,
#    578074,
#    102081,
#    385770,
#    127157,
#    554563,
#    452236,
#    153971,
#    520449,
#    223721,
#    640604,
#    330283,
#    3588,
#    309690,
#    169824,
#    620519,
#    606253,
#    528474,
#    395438,
#    371469,
#    478923,
#    217180,
#    137994,
#    684283,
#    658847,
#    227602,
#    99279,
#    467164,
#    511496],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 68029,
#   'songs': [196200,
#    83715,
#    508826,
#    22973,
#    496601,
#    578008,
#    291675,
#    571689,
#    98352,
#    125277,
#    226459,
#    490043,
#    344253,
#    49644,
#    508868,
#    270958,
#    550172,
#    399623,
#    195920,
#    667708,
#    234106,
#    424209,
#    417922,
#    427478,
#    81072,
#    419793,
#    408244,
#    35310,
#    623527,
#    660549,
#    372106,
#    292143,
#    402413,
#    393800,
#    664144,
#    493528,
#    483020,
#    394233,
#    336222,
#    689889,
#    234296,
#    671535,
#    145960,
#    461300,
#    590691,
#    479194,
#    483745,
#    483451,
#    549386,
#    337629,
#    200701,
#    677547,
#    593178,
#    444787,
#    535658,
#    562137,
#    242313,
#    518658,
#    445566,
#    437701,
#    6528,
#    439170,
#    604312,
#    440294,
#    591549,
#    22720,
#    397154,
#    84483,
#    321453,
#    535530,
#    42735,
#    676841,
#    137260,
#    683184,
#    284591,
#    644827,
#    45387,
#    494327,
#    194002,
#    105436,
#    12918,
#    421749,
#    247548,
#    26552,
#    115345,
#    630469,
#    427359,
#    76575,
#    86751,
#    267526,
#    65059,
#    205549,
#    283778,
#    478994,
#    517716,
#    54191,
#    184825,
#    661639,
#    10823,
#    326652],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 142148,
#   'songs': [8893,
#    691723,
#    16025,
#    652380,
#    25021,
#    312622,
#    618682,
#    323202,
#    214788,
#    270832,
#    574684,
#    398397,
#    107441,
#    392372,
#    19609,
#    581504,
#    510808,
#    546967,
#    277256,
#    671908,
#    512596,
#    245158,
#    106495,
#    202116,
#    192815,
#    519866,
#    386412,
#    552410,
#    657399,
#    364953,
#    290029,
#    687987,
#    560140,
#    251072,
#    568727,
#    142813,
#    91191,
#    603646,
#    392717,
#    357237,
#    286678,
#    682164,
#    58242,
#    498915,
#    23097,
#    127883,
#    220036,
#    539213,
#    545719,
#    656758,
#    354903,
#    431602,
#    535835,
#    701506,
#    129212,
#    114378,
#    347008,
#    306881,
#    450580,
#    497723,
#    613113,
#    221951,
#    416023,
#    89104,
#    477997,
#    238735,
#    311358,
#    479821,
#    260973,
#    554538,
#    281951,
#    480572,
#    374599,
#    488801,
#    77037,
#    630498,
#    177187,
#    522446,
#    79838,
#    433119,
#    654659,
#    454907,
#    667369,
#    544796,
#    540472,
#    287619,
#    457315,
#    586625,
#    140983,
#    632203,
#    627266,
#    387983,
#    126766,
#    242398,
#    553667,
#    173958,
#    653805,
#    351373,
#    330249,
#    502053],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 113041,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 53440,
#   'songs': [516815,
#    290570,
#    482556,
#    365288,
#    286585,
#    560595,
#    556985,
#    622381,
#    103741,
#    246378,
#    557624,
#    457203,
#    517861,
#    31470,
#    674900,
#    129367,
#    325581,
#    300057,
#    227379,
#    123283,
#    380490,
#    253188,
#    114983,
#    529885,
#    328887,
#    126731,
#    631223,
#    393687,
#    282167,
#    187213,
#    354630,
#    616448,
#    519392,
#    654671,
#    300945,
#    251434,
#    265237,
#    179955,
#    633394,
#    700613,
#    453016,
#    279806,
#    258589,
#    158679,
#    425329,
#    608251,
#    372017,
#    688141,
#    484940,
#    576507,
#    506339,
#    157756,
#    70862,
#    637142,
#    631399,
#    42801,
#    168984,
#    252754,
#    138212,
#    313391,
#    386731,
#    244969,
#    138042,
#    525423,
#    176104,
#    705209,
#    85338,
#    255752,
#    121099,
#    113165,
#    416048,
#    197972,
#    341399,
#    434598,
#    485894,
#    557595,
#    674031,
#    575089,
#    61695,
#    328650,
#    510542,
#    362048,
#    211566,
#    57303,
#    214937,
#    567958,
#    462826,
#    366953,
#    337162,
#    424985,
#    91421,
#    55332,
#    664155,
#    119883,
#    304982,
#    568083,
#    188646,
#    388692,
#    100407,
#    161884],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 75895,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 132962,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 61648,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 87885,
#   'songs': [531675,
#    406229,
#    227210,
#    206587,
#    68093,
#    684224,
#    658697,
#    218478,
#    653546,
#    138704,
#    55553,
#    395137,
#    275361,
#    57978,
#    364016,
#    267901,
#    453469,
#    8646,
#    633943,
#    261912,
#    467067,
#    427110,
#    620645,
#    119690,
#    273670,
#    339028,
#    123139,
#    259148,
#    484832,
#    56035,
#    705049,
#    399181,
#    599677,
#    357436,
#    387141,
#    394374,
#    432541,
#    206429,
#    300734,
#    245671,
#    461944,
#    650770,
#    527315,
#    540649,
#    103656,
#    88580,
#    510910,
#    275831,
#    285663,
#    193474,
#    167955,
#    146388,
#    500646,
#    677258,
#    450118,
#    596021,
#    74190,
#    533880,
#    491037,
#    426940,
#    314166,
#    580449,
#    450064,
#    124413,
#    47094,
#    244865,
#    194813,
#    235986,
#    221085,
#    283276,
#    40558,
#    162199,
#    406620,
#    427998,
#    180225,
#    310775,
#    249063,
#    18723,
#    36372,
#    308983,
#    172245,
#    191315,
#    480504,
#    679095,
#    380488,
#    331043,
#    575722,
#    495924,
#    344974,
#    13583,
#    135593,
#    247855,
#    564963,
#    549267,
#    122586,
#    86139,
#    48883,
#    633470,
#    46264,
#    601748],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 139661,
#   'songs': [529598,
#    581976,
#    379215,
#    139576,
#    420005,
#    577658,
#    560368,
#    699792,
#    424170,
#    363333,
#    693214,
#    541541,
#    575507,
#    307177,
#    334462,
#    514862,
#    371710,
#    315550,
#    524076,
#    620080,
#    669737,
#    165492,
#    382712,
#    470574,
#    41463,
#    654191,
#    174895,
#    281670,
#    229441,
#    5695,
#    627569,
#    702626,
#    325054,
#    419012,
#    486981,
#    446008,
#    295367,
#    671823,
#    66216,
#    233876,
#    167362,
#    313065,
#    384650,
#    125025,
#    38539,
#    701850,
#    453125,
#    620310,
#    647371,
#    79301,
#    107969,
#    688263,
#    272430,
#    705459,
#    545629,
#    678795,
#    171754,
#    385430,
#    675298,
#    150441,
#    525322,
#    672673,
#    607661,
#    635245,
#    194750,
#    673420,
#    707552,
#    564523,
#    575767,
#    251753,
#    244258,
#    532427,
#    655191,
#    594210,
#    317377,
#    632561,
#    511262,
#    304363,
#    474457,
#    401985,
#    432521,
#    629112,
#    66262,
#    293568,
#    127791,
#    349023,
#    184187,
#    548756,
#    86662,
#    685437,
#    604050,
#    566447,
#    114697,
#    584038,
#    607488,
#    636595,
#    135196,
#    18995,
#    98665,
#    202222],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 1140,
#   'songs': [532923,
#    500186,
#    424808,
#    221689,
#    656785,
#    315201,
#    331102,
#    232148,
#    286746,
#    431512,
#    642699,
#    497248,
#    496787,
#    410953,
#    249378,
#    619557,
#    614202,
#    11349,
#    46489,
#    230793,
#    407483,
#    289493,
#    178714,
#    9942,
#    621329,
#    699398,
#    464849,
#    453026,
#    63458,
#    686515,
#    77645,
#    259994,
#    382225,
#    141388,
#    127688,
#    524098,
#    366699,
#    135182,
#    609452,
#    570245,
#    151498,
#    624257,
#    155360,
#    95189,
#    35568,
#    277951,
#    80899,
#    203865,
#    604925,
#    459415,
#    570612,
#    36095,
#    398874,
#    140047,
#    241847,
#    383580,
#    542935,
#    422338,
#    379913,
#    218663,
#    14222,
#    189982,
#    612167,
#    146150,
#    615741,
#    705983,
#    630326,
#    274081,
#    71330,
#    496459,
#    357318,
#    680676,
#    479170,
#    675367,
#    3634,
#    415742,
#    304138,
#    420191,
#    319540,
#    167682,
#    74032,
#    298614,
#    634479,
#    75606,
#    531319,
#    522206,
#    430940,
#    158832,
#    405831,
#    254283,
#    272193,
#    695926,
#    118669,
#    652797,
#    496398,
#    556696,
#    418405,
#    564022,
#    556251,
#    583490],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 29582,
#   'songs': [473044,
#    212686,
#    273592,
#    429474,
#    347525,
#    86512,
#    578453,
#    391570,
#    291633,
#    605550,
#    192074,
#    509694,
#    677929,
#    643501,
#    213099,
#    117104,
#    23772,
#    592389,
#    493668,
#    330579,
#    151953,
#    295492,
#    253225,
#    515609,
#    265717,
#    559162,
#    641732,
#    345618,
#    96692,
#    556810,
#    609225,
#    707594,
#    59116,
#    567196,
#    128393,
#    193564,
#    310938,
#    350030,
#    308832,
#    171210,
#    269773,
#    212114,
#    505243,
#    400339,
#    308867,
#    119102,
#    554286,
#    505293,
#    83566,
#    439581,
#    144193,
#    506985,
#    161705,
#    394234,
#    207,
#    636457,
#    447991,
#    493500,
#    123713,
#    149276,
#    221341,
#    292847,
#    655623,
#    162043,
#    339412,
#    103099,
#    151476,
#    146174,
#    433844,
#    269706,
#    705349,
#    263582,
#    113676,
#    412073,
#    701063,
#    692563,
#    124325,
#    462599,
#    498840,
#    602080,
#    136320,
#    22335,
#    573629,
#    462362,
#    83802,
#    62757,
#    6411,
#    319467,
#    160695,
#    310306,
#    273621,
#    270266,
#    199283,
#    599228,
#    620930,
#    44250,
#    632529,
#    292466,
#    149229,
#    597386],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 93094,
#   'songs': [100364,
#    641935,
#    394670,
#    345033,
#    209472,
#    13523,
#    594703,
#    184626,
#    495266,
#    506479,
#    316092,
#    73204,
#    404067,
#    5529,
#    65367,
#    178725,
#    326710,
#    124693,
#    693564,
#    395771,
#    122109,
#    365402,
#    653781,
#    145692,
#    136652,
#    230309,
#    659168,
#    166635,
#    436095,
#    434728,
#    634921,
#    337107,
#    396871,
#    697216,
#    458606,
#    490243,
#    140427,
#    232175,
#    334575,
#    450366,
#    633769,
#    284384,
#    458514,
#    540016,
#    419891,
#    172047,
#    151430,
#    367225,
#    146036,
#    395580,
#    238173,
#    416790,
#    141770,
#    643014,
#    231642,
#    561318,
#    50555,
#    275594,
#    234190,
#    44021,
#    549510,
#    704564,
#    700739,
#    568303,
#    416466,
#    364457,
#    678331,
#    523072,
#    546732,
#    216719,
#    389768,
#    484187,
#    278413,
#    311786,
#    355247,
#    2178,
#    464684,
#    299948,
#    3603,
#    669094,
#    146668,
#    470928,
#    471826,
#    103944,
#    555285,
#    540200,
#    271649,
#    314016,
#    595089,
#    49682,
#    69099,
#    572342,
#    612088,
#    693515,
#    124982,
#    411650,
#    97348,
#    189877,
#    673347,
#    118222],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 38311,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 18862,
#   'songs': range(1, 101),
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 56098,
#   'songs': [204931,
#    657577,
#    17497,
#    101388,
#    473403,
#    130440,
#    382469,
#    498995,
#    449565,
#    150065,
#    200121,
#    610428,
#    138194,
#    532964,
#    324559,
#    448744,
#    273847,
#    84191,
#    207231,
#    103210,
#    80671,
#    651644,
#    406527,
#    396325,
#    158158,
#    373027,
#    412549,
#    196231,
#    675303,
#    603871,
#    539106,
#    452901,
#    100590,
#    509600,
#    509568,
#    389468,
#    386378,
#    245017,
#    176262,
#    705979,
#    464489,
#    649849,
#    351101,
#    140961,
#    128015,
#    68596,
#    37124,
#    524172,
#    208812,
#    51633,
#    313050,
#    640406,
#    396644,
#    547966,
#    682709,
#    401742,
#    693855,
#    393007,
#    46173,
#    300803,
#    565159,
#    304639,
#    673525,
#    518897,
#    511558,
#    339059,
#    272465,
#    562242,
#    548293,
#    87100,
#    518185,
#    415787,
#    124940,
#    133868,
#    475530,
#    187863,
#    207220,
#    629738,
#    153622,
#    627237,
#    24922,
#    371155,
#    308768,
#    500558,
#    340922,
#    397436,
#    85360,
#    366018,
#    303955,
#    4469,
#    249595,
#    578913,
#    362411,
#    489554,
#    156922,
#    175391,
#    254518,
#    35874,
#    278367,
#    569664],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 25909,
#   'songs': [514474,
#    692078,
#    117041,
#    194925,
#    547676,
#    684939,
#    384358,
#    268606,
#    419842,
#    239743,
#    204855,
#    272136,
#    654267,
#    43589,
#    622047,
#    481400,
#    440867,
#    283413,
#    146147,
#    226374,
#    422887,
#    502176,
#    473494,
#    259649,
#    367924,
#    234948,
#    267809,
#    277851,
#    285411,
#    452524,
#    117402,
#    679901,
#    546200,
#    290761,
#    373773,
#    706831,
#    527674,
#    601447,
#    394617,
#    189898,
#    527926,
#    271353,
#    495381,
#    93038,
#    287719,
#    403252,
#    651730,
#    290816,
#    560285,
#    580644,
#    138993,
#    539747,
#    689278,
#    366082,
#    17757,
#    413381,
#    221697,
#    52928,
#    110957,
#    576193,
#    370718,
#    134899,
#    95519,
#    237073,
#    151540,
#    189214,
#    226390,
#    26784,
#    575712,
#    86316,
#    533832,
#    455259,
#    609549,
#    192198,
#    146559,
#    620738,
#    615143,
#    561154,
#    50079,
#    602655,
#    396812,
#    9596,
#    118751,
#    541858,
#    208068,
#    23446,
#    478014,
#    56987,
#    575692,
#    608325,
#    567813,
#    120249,
#    236501,
#    93618,
#    149241,
#    342647,
#    464941,
#    705007,
#    273665,
#    394671],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  {'id': 58737,
#   'songs': [263941,
#    157055,
#    516707,
#    165495,
#    680366,
#    221744,
#    302299,
#    68348,
#    462057,
#    486551,
#    658431,
#    12170,
#    373881,
#    265174,
#    267414,
#    75399,
#    677825,
#    90693,
#    468589,
#    70526,
#    590513,
#    690604,
#    66005,
#    578635,
#    275824,
#    621450,
#    259612,
#    112282,
#    674624,
#    625254,
#    215411,
#    523521,
#    384188,
#    268915,
#    124144,
#    239135,
#    3858,
#    546698,
#    463173,
#    159757,
#    481846,
#    187047,
#    578283,
#    341513,
#    420836,
#    637672,
#    621927,
#    235773,
#    451970,
#    487911,
#    563892,
#    442014,
#    707948,
#    42155,
#    520093,
#    422921,
#    38261,
#    259368,
#    673796,
#    448116,
#    105140,
#    612343,
#    125515,
#    200703,
#    52026,
#    223071,
#    318467,
#    85845,
#    582252,
#    227329,
#    14510,
#    65363,
#    490970,
#    199262,
#    248412,
#    94186,
#    427724,
#    211964,
#    683564,
#    233140,
#    433037,
#    514576,
#    554414,
#    578321,
#    106034,
#    357516,
#    349492,
#    219020,
#    306883,
#    394952,
#    143804,
#    176093,
#    529069,
#    348203,
#    17908,
#    209318,
#    668703,
#    209993,
#    393775,
#    253721],
#   'tags': ['타린',
#    '간지러워',
#    '점수',
#    '에드시런셋리스트',
#    '첩보영화',
#    '우아한',
#    '화사한',
#    '피아노',
#    '힙합스타일',
#    '싱숭생숭']},
#  ...]
